# %%
import os
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\bestl\\OneDrive\\바탕 화면\\24-1\\종합설계\\dataset_origin\\채용 병합'

# %%
#df = pd.read_csv('merged_hire.csv')
#최종합병
df = pd.read_csv("merged_hire_final.csv")

# %%
df = pd.read_csv("merged_hire_final.csv")
df
# Out:
#       index        date                                      title  \
# 0      1269  2024.03.28                         국제학사 공로봉사장학생 모집 안내
# 1      1268  2024.03.27                     [사이버외대 영어학부] 전임조교 모집공지
# 2      1267  2024.03.27                             중국연구소 전임연구원 모집
# 3      1266  2024.03.26                         한국외국어대학교 신입직원 채용공고
# 4      1265  2024.03.25  2024학년도 국제여름학기 Workstudy 장학생 모집 공고 (~4/8)
# ...     ...         ...                                        ...
# 1264      2  2020.01.06       한국외국어대학교 계약직 채용공고_사업본부운영2팀(한국어문화교육원)
# 1265      1  2020.01.02              2020-1 국제학부 수석조교(대학원생조교) 모집안내
# 1266    602  2022.02.23        (22-1) 외국어교육센터(글로벌) 수직조교 2차 추가모집 공고
# 1267    601  2022.02.23       (22-1) 외국어교육센터(글로벌) 대학원조교 2차 추가모집 공고
# 1268    600  2022.02.21                 사이버한국외국어대학교 한국어학부 행정 조교 모집
#
#                                                 content
# 0     \n국제학사 사감 모집 공고(여 대학원생) \n\n1. 모집 관련 일반사항\n가. ...
# ...

# %%
refer = pd.read_csv("merged_hire - 복사본.csv", encoding = "cp949")
refer.loc[3,'content']
df.loc[3,'content']
# Out:
# '한국외국어대학교 신입직원 채용공고\n\n신입직원 채용공고\n2024.04.01(월) 14:00-04.14(일) 14:00\n1. 채용 공통지원 자격\n-본교 인사규정상 임용기준 및 국가공무원 임용기준 결격사유가 없는 자\n- 해외여행에 결격사유가 없는 자\n-남자는 병역필 또는 면제자\n-성 관련 범죄나 직장(학교) 내 괴롭힘 행위의 전력이 없는 자\n\n※ 적임자가 없을 경우 채용하지 않을 수 있음\n\n2. 채용 지원자격\n직종: 일반직\n인원:00명\n필수 지원자격 및 우대사항\n○ 필수지원자격 (아래 자격 1.~2. 모두 충족해야 함)\n자격 1. 4년제 정규대학 졸업자 (2024년 8월 졸업예정자 지원가능)\n자격 2. FLEX 영어(듣기/읽기) 763점 이상, TOEIC 850점 이상, TOEFL IBT 100점 이상 중 택1\n※공인어학성적은 2022년 6월 1일 이후 취득한 성적만 인정하며, 접수마감일 이전에 취득한 영어 성적이 있어야지원 가능함 (국외시험/특별시험 및 IBT"My Best Score"인정하지 않음)\n\nᄋ우대사항\n[공통]\n1. 대학행정업무 경력 1년 이상자\n2. 상경, 법학, 교육, 통계 전공자\n3. OA프로그램 사용능숙자\n[국제분야]\n1. FLEX 영어(말하기) 2B 이상, TOEIC Speaking Level. 6(또는 IM 130/ IM3) 이상, OPIc IM3 이상\n2. 중국어 HSK 5급이상자, 기타 외국어 능통자\n3. 대학행정업무(국제) 경력자\n3. 채용예정자 신분\n-채용일로부터 6개월간 계약직 임용\n・근무평가(심사) 우수자는 평가결과에 따라 정규직 전환 가능\n•정규직 임용 후 호봉제에 의한 급여 적용\n-신입직원으로 임용하며, 기존경력은 인정하지 않음\n\n4. 전형일정\n지원서 접수\n1차 : 서류전형\n2차 : AI인적성검사(AI면접포함)\n3차: 역량면접\n4차 : 심화면접\n5차 : 최종면접\n※ AI인적성검사에서 조직부적응 진단결과 및 응답신뢰도 이상 있을 경우 총점과 관계없이
# ...

# %%
#날짜 검색
#print(df.loc[df['date'] == '2018.06.26'])
#인덱스 검색
print(df.loc[df['index'] ==  1266])
# Out:
#    index        date               title  \
# 3   1266  2024.03.26  한국외국어대학교 신입직원 채용공고
#
#                                              content
# 3  \n한국외국어대학교 신입직원 채용공고\n\n\n[4월1일 접수 예정]한국외국어대학교...

# %%
print(df.loc[3,'content'])
# Out:
# 한국외국어대학교 신입직원 채용공고
#
#
# [4월1일 접수 예정]한국외국어대학교 신입직원 채용 인터넷 접수  바로가기

# %%
df.loc[3,'content'] = """한국외국어대학교 신입직원 채용공고

신입직원 채용공고
2024.04.01(월) 14:00-04.14(일) 14:00
1. 채용 공통지원 자격
-본교 인사규정상 임용기준 및 국가공무원 임용기준 결격사유가 없는 자
- 해외여행에 결격사유가 없는 자
-남자는 병역필 또는 면제자
-성 관련 범죄나 직장(학교) 내 괴롭힘 행위의 전력이 없는 자

※ 적임자가 없을 경우 채용하지 않을 수 있음

2. 채용 지원자격
직종: 일반직
인원:00명
필수 지원자격 및 우대사항
○ 필수지원자격 (아래 자격 1.~2. 모두 충족해야 함)
자격 1. 4년제 정규대학 졸업자 (2024년 8월 졸업예정자 지원가능)
자격 2. FLEX 영어(듣기/읽기) 763점 이상, TOEIC 850점 이상, TOEFL IBT 100점 이상 중 택1
※공인어학성적은 2022년 6월 1일 이후 취득한 성적만 인정하며, 접수마감일 이전에 취득한 영어 성적이 있어야지원 가능함 (국외시험/특별시험 및 IBT"My Best Score"인정하지 않음)

ᄋ우대사항
[공통]
1. 대학행정업무 경력 1년 이상자
2. 상경, 법학, 교육, 통계 전공자
3. OA프로그램 사용능숙자
[국제분야]
1. FLEX 영어(말하기) 2B 이상, TOEIC Speaking Level. 6(또는 IM 130/ IM3) 이상, OPIc IM3 이상
2. 중국어 HSK 5급이상자, 기타 외국어 능통자
3. 대학행정업무(국제) 경력자
3. 채용예정자 신분
-채용일로부터 6개월간 계약직 임용
・근무평가(심사) 우수자는 평가결과에 따라 정규직 전환 가능
•정규직 임용 후 호봉제에 의한 급여 적용
-신입직원으로 임용하며, 기존경력은 인정하지 않음

4. 전형일정
지원서 접수
1차 : 서류전형
2차 : AI인적성검사(AI면접포함)
3차: 역량면접
4차 : 심화면접
5차 : 최종면접
※ AI인적성검사에서 조직부적응 진단결과 및 응답신뢰도 이상 있을 경우 총점과 관계없이 탈락
※ 상기 전형일정은 학사일정 및 전형진행 상황에 따라 변경될 수 있으며, 단계별 일정 변경 시 대상 지원자에게 개별안내 예정
5. 접수방법 및 서류제출
접수방법 : 학교홈페이지 접수 (채용공지 게시판 및 공고문 하단 "인터넷 접수 " 바로가기 배너 참조)
- 서류제출 (2차전형 합격자에 한하여 3차 면접일 제출 (미제출시 불합격 처리됨)
1 학부(필수)/대학원(해당자) 졸업증명서 1부 ※ 2024년 8월 졸업예정자의 경우 졸업예정증명서 1부
2 학부(필수)/대학원(해당자) 성적증명서 1부
3 공인어학성적표 원본(해당자) 1부 (지원서 기재성적으로 2022년 6월 1일 이후 취득한 성적만 인정)
4 경력증명서(지원서 기재 경력만) 1부
5 자격증사본(지원서 기재 자격증) 1부- 제출 시 원본 지참
6 교육/연수 증빙서류(지원서 기재 내용만) 1부
7 국가보훈대상자 및 장애인 관련 서류(해당자)
※ 경력증명서는 3개월 이내 발급된 것만 인정하며 발행기관 담당자 성명 또는 연락처가 표기된 서류로 제출요망
(경력증명서 내 담당자 성명, 연락처 미포함 시 하단에 별도 기재 요망)
6. 기타사항
해당분야에 적격자가 없을 경우 채용하지 않을 수 있음
- 서류전형 합격자는 본교 홈페이지에 발표함
- 접수마감 시간에는 동시 접속으로 인해 접수가 어려울 수 있으므로 접수마감 시간 전 접수완료 하시기 바라며, 접수완료 후 입사지원서 수정은 불가함
- 서류접수 결과 지원자가 서류전형 합격예정 인원보다 적은 경우 재공고 또는 공고기간 연장 가능
필수지원자격의 적합 여부를 반드시 확인한 후 입사지원서를 제출하시기 바라며, 입사지원서의 기재착오, 누락 및
지원자의 합격 여부 미확인, 연락불능 등으로 인한 불이익은 지원자의 귀책사유임
- 입사지원서 기재내용 및 제출서류 내용 중 허위사실이 발견되거나 신체검사 및 신원조회에 이상이 있는 경우 합격이 취소됨
- 근무지는 서울캠퍼스 또는 글로벌캠퍼스(용인) 순환근무임
신입직원의 보수는 학교 보수규정에 정한 바에 따름
졸업예정자의 경우 졸업예정일에 졸업을 하지 못하는 경우 임용이 취소됨
- 국가보훈대상자(취업지원대상자) 및 장애인 우대

7. 채용서류의 반환
근거법령 : 채용절차 공정화에 관한 법률 제 11조
1 최종합격자를 제외한 구직자가 전형단계별 채용여부가 확정된 날부터 30일이 되는 날까지 전형단계별 제출서류의 반환을 청구하는 경우 기 제출한 서류를 반환받을 수 있음. 다만, 홈페이지 또는 전자우편으로 제출된 경우나 구직자가 학교의 요구 없이 자발적으로 제출한 경우에는 그러하지 아니하며, 천재지변이나 그 밖에 학교에 책임 없는 사유로 제출서류가 멸실된 경우에는 반환한 것으로 봄.
2 제출서류 반환 청구를 하려는 구직자는 채용서류 반환청구서(채용절차의 공정화에 관한 법률 시행규칙 별지 제3호 서식)를 작성하여 이메일 (hrd@hufs.ac.kr)로 제출하면 제출이 확인된 날부터 14일 이내 지정한 주소지로 등기우편을 통하여 발송해 드리며, 상황에 따라 등기우편요금은 수신자 부담으로 처리 될 수 있으니 유념하시기 바람.
3 학교는 구직자의 반환 청구에 대비하여 전형단계별 채용여부가 확정된 날부터 30일이 되는날까지 제출서류를 보관하게 되며, 그 때까지 채용서류 의 반환을 청구하지 아니할 경우에는 개인정보보호법에 따라 지체 없이 채용서류 일체를 파기할 예정임.
8. 문의처
한국외국어대학교 인사팀 (02-2173-2163~4 3524, hrd@hufs.ac.kr)

"""

# %%
# 저장 및 병합
df.to_csv("merged_hire_final.csv", index=False)
df = pd.read_csv("merged_hire_final.csv")
