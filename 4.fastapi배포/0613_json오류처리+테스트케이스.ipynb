# %% [markdown]
# # Fastapi 배포

# %% [markdown]
# - 참고링크: https://colab.research.google.com/drive/1HWkV-PJaAAO8lz3RDzsFUJ1meeE4GYHA?usp=sharing#scrollTo=6tLUT6T9FjHG

# %% [markdown]
# ## 의존성 설치

# %%
# !pip install fastapi
# !pip install uvicorn
# !pip install pickle5
# !pip install pydantic
# !pip install scikit-learn
# !pip install requests
# !pip install pypi-json
# !pip install pyngrok
# !pip install nest-asyncio
# Out:
# Collecting fastapi
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 1.5 MB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.7.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.1)
# Collecting fastapi-cli>=0.0.2 (from fastapi)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting httpx>=0.23.0 (from fastapi)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.9 MB/s eta 0:00:00
# Collecting orjson>=3.2.1 (from fastapi)
#   Downloading orjson-3.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 2.2 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi)
#   Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Collecting uvicorn[standard]>=0.12.0 (from fastapi)
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.3 MB/s eta 0:00:00
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Collecting typer>=0.12.3 (from fastapi-cli>=0.0.2->fastapi)
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.23.0->fastapi)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.18.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi) (8.1.7)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 27.1 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 38.8 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.0 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.23.0->fastapi) (1.2.1)
# Collecting shellingham>=1.3.0 (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# Installing collected packages: websockets, uvloop, ujson, shellingham, python-multipart, python-dotenv, orjson, httptools, h11, dnspython, watchfiles, uvicorn, starlette, httpcore, email_validator, typer, httpx, fastapi-cli, fastapi
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# Successfully installed dnspython-2.6.1 email_validator-2.1.1 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 orjson-3.10.4 python-dotenv-1.0.1 python-multipart-0.0.9 shellingham-1.5.4 starlette-0.37.2 typer-0.12.3 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (0.30.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (4.12.1)
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255316 sha256=7911ea492415b6d635a81403bb19f93b4af17555694f8941d3fac551996280b3
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (2.7.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic) (4.12.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Collecting pypi-json
#   Downloading pypi_json-0.4.0-py3-none-any.whl (26 kB)
# Collecting apeye>=1.1.0 (from pypi-json)
#   Downloading apeye-1.4.1-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.10/dist-packages (from pypi-json) (24.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from pypi-json) (2.31.0)
# Collecting apeye-core>=1.0.0b2 (from apeye>=1.1.0->pypi-json)
#   Downloading apeye_core-1.1.5-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.3/99.3 kB 14.4 MB/s eta 0:00:00
# Collecting domdf-python-tools>=2.6.0 (from apeye>=1.1.0->pypi-json)
#   Downloading domdf_python_tools-3.8.1-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from apeye>=1.1.0->pypi-json) (4.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (2024.6.2)
# Requirement already satisfied: natsort>=7.0.1 in /usr/local/lib/python3.10/dist-packages (from domdf-python-tools>=2.6.0->apeye>=1.1.0->pypi-json) (8.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from domdf-python-tools>=2.6.0->apeye>=1.1.0->pypi-json) (4.12.1)
# Installing collected packages: domdf-python-tools, apeye-core, apeye, pypi-json
# Successfully installed apeye-1.4.1 apeye-core-1.1.5 domdf-python-tools-3.8.1 pypi-json-0.4.0
# Collecting pyngrok
#   Downloading pyngrok-7.1.6-py3-none-any.whl (22 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.1.6
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)

# %%
# lovit 가져오기
# 패키지
# !pip install git+https://github.com/lovit/textrank.git
# 깃 클론
# !git clone https://github.com/lovit/textrank.git
# 이제 리포지토리의 코드를 사용할 수 있습니다.
from textrank import KeywordSummarizer, KeysentenceSummarizer
# Out:
# Collecting git+https://github.com/lovit/textrank.git
#   Cloning https://github.com/lovit/textrank.git to /tmp/pip-req-build-g27f4kzo
#   Running command git clone --filter=blob:none --quiet https://github.com/lovit/textrank.git /tmp/pip-req-build-g27f4kzo
#   Resolved https://github.com/lovit/textrank.git to commit 578c7fbbb22b24561b1bd4bab9a9ecc2dc9515e1
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: textrank
#   Building wheel for textrank (setup.py) ... done
#   Created wheel for textrank: filename=textrank-0.1.2-py3-none-any.whl size=11142 sha256=005083c6d3d15a7ca8fe40506672038f8195802ce6d26f9c7f5db15cafb78356
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x3p2_leq/wheels/8d/d1/ef/7c6abc0d5bbb64f01bd86b0ad967911d4b7f21bb44813b3239
# Successfully built textrank
# Installing collected packages: textrank
# Successfully installed textrank-0.1.2
# Cloning into 'textrank'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 232 (delta 1), reused 1 (delta 0), pack-reused 225
# Receiving objects: 100% (232/232), 1.21 MiB | 4.05 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
#konlpy가져오기
#konlpy 다운 및 호출
#1. Konlpy에서 Okt
# !pip install konlpy
#2. konlpy 실행을 위한 자바어쩌구 다운
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#3. 필요한 설정
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
from konlpy.tag import Okt
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 30.8 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 41.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %% [markdown]
# ### 사용자 사전 정의

# %%
# 사용자 사전 찾아가기 및 경로 설정 _ 여기서 오류가 날 시 코랩에서 폴더 열어서 usr,local 찾아가보시며 폴더명이 일치하는지 확인해보세요! 보통 파이썬 버전이 다릅니다.
os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java')
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages/konlpy/java'

# %%
#jar파일을 풀어줄 폴더이름을 정합니다. 저는 temp_fix로 했어요!
os.makedirs('./temp_fix')
os.chdir('./temp_fix')
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix'

# %%
#inflated어쩌고 쭉뜨고 맨끝에 에러 없으면 잘된겁니다!
# !jar xvf ../open-korean-text-2.1.0.jar
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#   created: org/openkoreantext/processor/normalizer/
#   created: org/openkoreantext/processor/phrase_extractor/
#   created: org/openkoreantext/processor/qa/
#   created: org/openkoreantext/processor/stemmer/
#   created: org/openkoreantext/processor/tokenizer/
#   created: org/openkoreantext/processor/tools/
#   created: org/openkoreantext/processor/util/
#   created: org/openkoreantext/processor/util/adjective/
#   created: org/openkoreantext/processor/util/adverb/
#   created: org/openkoreantext/processor/util/auxiliary/
#   created: org/openkoreantext/processor/util/freq/
#   created: org/openkoreantext/processor/util/josa/
#   created: org/openkoreantext/processor/util/noun/
#   created: org/openkoreantext/processor/util/substantives/
#   created: org/openkoreantext/processor/util/typos/
#   created: org/openkoreantext/processor/util/verb/
#  inflated: org/openkoreantext/processor/KoreanPosJava.class
#  inflated: org/openkoreantext/processor/KoreanTokenJava.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor$.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer$.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence$.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile$.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class
#  inflated: org/openkoreantext/processor/tools/Runnable.class
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples$.class
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples.class
#  inflated: org/openkoreantext/processor/util/adjective/adjective.txt
#  inflated: org/openkoreantext/processor/util/adverb/adverb.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/conjunctions.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/determiner.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/exclamation.txt
#  inflated: org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$1.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$MapEntry.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArraySet.class
#  inflated: org/openkoreantext/processor/util/example_chunks.txt
#  inflated: org/openkoreantext/processor/util/example_tweets.txt
#  inflated: org/openkoreantext/processor/util/freq/entity-freq.txt.gz
#  inflated: org/openkoreantext/processor/util/Hangul$.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda$.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar$.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar.class
#  inflated: org/openkoreantext/processor/util/Hangul.class
#  inflated: org/openkoreantext/processor/util/josa/josa.txt
#  inflated: org/openkoreantext/processor/util/KoreanConjugation$.class
#  inflated: org/openkoreantext/processor/util/KoreanConjugation.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider$.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class
#  inflated: org/openkoreantext/processor/util/KoreanPos.class
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive$.class
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive.class
#  inflated: org/openkoreantext/processor/util/noun/bible.txt
#  inflated: org/openkoreantext/processor/util/noun/company_names.txt
#  inflated: org/openkoreantext/processor/util/noun/congress.txt
#  inflated: org/openkoreantext/processor/util/noun/entities.txt
#  inflated: org/openkoreantext/processor/util/noun/foreign.txt
#  inflated: org/openkoreantext/processor/util/noun/geolocations.txt
#  inflated: org/openkoreantext/processor/util/noun/kpop.txt
#  inflated: org/openkoreantext/processor/util/noun/lol.txt
#  inflated: org/openkoreantext/processor/util/noun/names.txt
#  inflated: org/openkoreantext/processor/util/noun/nouns.txt
#  inflated: org/openkoreantext/processor/util/noun/pokemon.txt
#  inflated: org/openkoreantext/processor/util/noun/profane.txt
#  inflated: org/openkoreantext/processor/util/noun/slangs.txt
#  inflated: org/openkoreantext/processor/util/noun/spam.txt
#  inflated: org/openkoreantext/processor/util/noun/twitter.txt
#  inflated: org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt
#  inflated: org/openkoreantext/processor/util/substantives/family_names.txt
#  inflated: org/openkoreantext/processor/util/substantives/given_names.txt
#  inflated: org/openkoreantext/processor/util/substantives/modifier.txt
#  inflated: org/openkoreantext/processor/util/substantives/suffix.txt
#  inflated: org/openkoreantext/processor/util/typos/typos.txt
#  inflated: org/openkoreantext/processor/util/verb/eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/pre_eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/verb.txt
채용일\n추후 협의\n증빙서류\n제출목록\n지원서\n온라인지원\n졸업증명서\n성적증명서\n학사\n석사\n박사\n업로드\n성범죄 경력조회서\n경력증명서\n발급본\n지원 기간\n접수 방법\n사업본부\n개별 통보\n개별 통지\n연구보조원\n숙련자\n웹페이지\nKMOOC\n인문사회계열\n전형방법\n서류전형\n면접대상자\n줌주소\n실습데이터\nZOOM데스크탑앱\n포트폴리오\n지원서 접수\n압축파일\nzip\n학생상담센터\n개인상담\n집단상담\n대학혁신지원사업\n상담센터\n석사학위\n소지자\n경력(재직)증명서\n개인정보동의서\n별첨양식\n교직원 출퇴근 셔틀버스\n출퇴근\n교직원\n이문동\n잠실\n분당\n노선\n오피스\n스페인어\n포르투갈어\n석사\n재학생\nHK연구소\n중남미연구소\n내부규정\n급여\n계약기간\n교내외장학금\n사회 배려계층\n교무행정팀\n객원상담원\n겸임교수\n초빙교수\n초빙공고\n정보통신공학과\n재공고\n시설관리팀\n수목관리\n직원인사규정\n제11조\n임용결격사유\n1종보통 운전면허\n외국인학생\n여름방학\n민원응대\n봉사장학금\n장학금지급규정\n등록금 범위내\n국제학사\nGlobeeDorm\n학사운영팀\n중국연구소\n전임연구원\n최종학위증명서\n이력서\n자율양식\n경력증명서\n채용예정일\n지식출판콘텐츠원\n채용공고\n경영기획팀\n행정\n학사학위\n국고사업\n관련법\n연구산학협력단\n러시아연구소\n초빙분야\n세부전공\n인센티브\n4대 보험\n한국연구재단\n인문한국플로스지원사업\n사립학교\n해당 분야\n기초심사\n전공면접\n경기도 용인시 처인구 모현면 외대로 81\n국제사회교육원\n러시아연구소\n육아휴직\n학술정보팀\n퇴직금\nTESOL\nFLEX센터\n능숙자\nOA프로그램\n영어회화\n관련업무\n유경험자\n근무 가능자\근무 가능\n장학생\n재학생\n언어 능력\n설명회\n선착순\n국제입학관리팀\n"

# %%
# 파일 새롭게 저장
with open("/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)
# !jar cvf ../open-korean-text-2.1.0.jar *
# Out:
# added manifest
# ignoring entry META-INF/
# ignoring entry META-INF/MANIFEST.MF
# adding: META-INF/maven/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.xml(in = 9127) (out= 2208)(deflated 75%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.properties(in = 119) (out= 110)(deflated 7%)
# adding: org/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor$.class(in = 7716) (out= 2400)(deflated 68%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class(in = 5901) (out= 1995)(deflated 66%)
# adding: org/openkoreantext/processor/stemmer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/stemmer/KoreanStemmer.class(in = 1439) (out= 972)(deflated 32%)
# adding: org/openkoreantext/processor/stemmer/KoreanStemmer$.class(in = 7044) (out= 2892)(deflated 58%)
# adding: org/openkoreantext/processor/tools/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class(in = 833) (out= 566)(deflated 32%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class(in = 2974) (out= 1020)(deflated 65%)
# adding: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class(in = 1117) (out= 823)(deflated 26%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$.class(in = 5881) (out= 2385)(deflated 59%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class(in = 3825) (out= 1443)(deflated 62%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class(in = 5989) (out= 2472)(deflated 58%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples.class(in = 2427) (out= 1732)(deflated 28%)
# adding: org/openkoreantext/processor/tools/Runnable.class(in = 964) (out= 694)(deflated 28%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class(in = 2516) (out= 1784)(deflated 29%)
# adding: org/openkoreantext/processor/tools/UpdateAllTheExamples.class(in = 1089) (out= 756)(deflated 30%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class(in = 2787) (out= 997)(deflated 64%)
# adding: org/openkoreantext/processor/tools/UpdateAllTheExamples$.class(in = 4383) (out= 1794)(deflated 59%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$.class(in = 5517) (out= 2327)(deflated 57%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class(in = 3718) (out= 1429)(deflated 61%)
# adding: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class(in = 7154) (out= 3133)(deflated 56%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples.class(in = 2367) (out= 1659)(deflated 29%)
# adding: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class(in = 5487) (out= 2305)(deflated 57%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class(in = 3569) (out= 1415)(deflated 60%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class(in = 2842) (out= 1010)(deflated 64%)
# adding: org/openkoreantext/processor/util/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/KoreanSubstantive$.class(in = 14990) (out= 6195)(deflated 58%)
# adding: org/openkoreantext/processor/util/verb/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/verb/eomi.txt(in = 12618) (out= 3556)(deflated 71%)
# adding: org/openkoreantext/processor/util/verb/verb_prefix.txt(in = 47) (out= 52)(deflated -10%)
# adding: org/openkoreantext/processor/util/verb/pre_eomi.txt(in = 285) (out= 185)(deflated 35%)
# adding: org/openkoreantext/processor/util/verb/verb.txt(in = 32758) (out= 10723)(deflated 67%)
# adding: org/openkoreantext/processor/util/Hangul$DoubleCoda$.class(in = 2155) (out= 963)(deflated 55%)
# adding: org/openkoreantext/processor/util/CharArraySet.class(in = 4886) (out= 1944)(deflated 60%)
# adding: org/openkoreantext/processor/util/KoreanSubstantive.class(in = 1336) (out= 1087)(deflated 18%)
# adding: org/openkoreantext/processor/util/auxiliary/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/auxiliary/exclamation.txt(in = 1759) (out= 757)(deflated 56%)
# adding: org/openkoreantext/processor/util/auxiliary/determiner.txt(in = 63) (out= 63)(deflated 0%)
# adding: org/openkoreantext/processor/util/auxiliary/conjunctions.txt(in = 398) (out= 189)(deflated 52%)
# adding: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class(in = 4390) (out= 1610)(deflated 63%)
# adding: org/openkoreantext/processor/util/adjective/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/adjective/adjective.txt(in = 27250) (out= 9357)(deflated 65%)
# adding: org/openkoreantext/processor/util/CharArrayMap$1.class(in = 1531) (out= 571)(deflated 62%)
# adding: org/openkoreantext/processor/util/Hangul.class(in = 3981) (out= 2731)(deflated 31%)
# adding: org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class(in = 2824) (out= 1393)(deflated 50%)
# adding: org/openkoreantext/processor/util/KoreanConjugation$.class(in = 22440) (out= 7972)(deflated 64%)
# adding: org/openkoreantext/processor/util/KoreanDictionaryProvider.class(in = 3430) (out= 2003)(deflated 41%)
# adding: org/openkoreantext/processor/util/KoreanPos.class(in = 6890) (out= 3877)(deflated 43%)
# adding: org/openkoreantext/processor/util/KoreanPos$.class(in = 12173) (out= 4669)(deflated 61%)
# adding: org/openkoreantext/processor/util/Hangul$.class(in = 7625) (out= 3114)(deflated 59%)
# adding: org/openkoreantext/processor/util/substantives/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/substantives/given_names.txt(in = 1407) (out= 609)(deflated 56%)
# adding: org/openkoreantext/processor/util/substantives/family_names.txt(in = 299) (out= 197)(deflated 34%)
# adding: org/openkoreantext/processor/util/substantives/modifier.txt(in = 3395) (out= 1346)(deflated 60%)
# adding: org/openkoreantext/processor/util/substantives/suffix.txt(in = 325) (out= 224)(deflated 31%)
# adding: org/openkoreantext/processor/util/Hangul$DoubleCoda.class(in = 2930) (out= 1348)(deflated 53%)
# adding: org/openkoreantext/processor/util/example_tweets.txt(in = 86271) (out= 38336)(deflated 55%)
# adding: org/openkoreantext/processor/util/Hangul$HangulChar.class(in = 3185) (out= 1421)(deflated 55%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class(in = 3118) (out= 1270)(deflated 59%)
# adding: org/openkoreantext/processor/util/example_chunks.txt(in = 522978) (out= 163253)(deflated 68%)
# adding: org/openkoreantext/processor/util/CharArrayMap.class(in = 11923) (out= 4878)(deflated 59%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class(in = 2788) (out= 1181)(deflated 57%)
# adding: org/openkoreantext/processor/util/CharacterUtils.class(in = 3703) (out= 1716)(deflated 53%)
# adding: org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class(in = 2577) (out= 1282)(deflated 50%)
# adding: org/openkoreantext/processor/util/noun/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/noun/entities.txt(in = 108142) (out= 44095)(deflated 59%)
# adding: org/openkoreantext/processor/util/noun/twitter.txt(in = 254) (out= 162)(deflated 36%)
# adding: org/openkoreantext/processor/util/noun/spam.txt(in = 202) (out= 157)(deflated 22%)
# adding: org/openkoreantext/processor/util/noun/slangs.txt(in = 1565) (out= 921)(deflated 41%)
# adding: org/openkoreantext/processor/util/noun/company_names.txt(in = 1631) (out= 905)(deflated 44%)
# adding: org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt(in = 1971964) (out= 686708)(deflated 65%)
# adding: org/openkoreantext/processor/util/noun/foreign.txt(in = 10485) (out= 4686)(deflated 55%)
# adding: org/openkoreantext/processor/util/noun/nouns.txt(in = 219319) (out= 84134)(deflated 61%)
# adding: org/openkoreantext/processor/util/noun/names.txt(in = 21485) (out= 6439)(deflated 70%)
# adding: org/openkoreantext/processor/util/noun/congress.txt(in = 26494) (out= 9351)(deflated 64%)
# adding: org/openkoreantext/processor/util/noun/lol.txt(in = 1337) (out= 744)(deflated 44%)
# adding: org/openkoreantext/processor/util/noun/bible.txt(in = 2032) (out= 1005)(deflated 50%)
# adding: org/openkoreantext/processor/util/noun/pokemon.txt(in = 1781) (out= 965)(deflated 45%)
# adding: org/openkoreantext/processor/util/noun/geolocations.txt(in = 5423) (out= 2267)(deflated 58%)
# adding: org/openkoreantext/processor/util/noun/profane.txt(in = 569) (out= 337)(deflated 40%)
# adding: org/openkoreantext/processor/util/noun/kpop.txt(in = 5371) (out= 2495)(deflated 53%)
# adding: org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class(in = 3062) (out= 859)(deflated 71%)
# adding: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class(in = 3157) (out= 1089)(deflated 65%)
# adding: org/openkoreantext/processor/util/josa/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/josa/josa.txt(in = 5219) (out= 1476)(deflated 71%)
# adding: org/openkoreantext/processor/util/KoreanConjugation.class(in = 1550) (out= 1237)(deflated 20%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class(in = 2053) (out= 725)(deflated 64%)
# adding: org/openkoreantext/processor/util/KoreanDictionaryProvider$.class(in = 20197) (out= 7488)(deflated 62%)
# adding: org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class(in = 1634) (out= 659)(deflated 59%)
# adding: org/openkoreantext/processor/util/freq/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/freq/entity-freq.txt.gz(in = 385753) (out= 385873)(deflated 0%)
# adding: org/openkoreantext/processor/util/Hangul$HangulChar$.class(in = 2389) (out= 1022)(deflated 57%)
# adding: org/openkoreantext/processor/util/typos/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/typos/typos.txt(in = 5146) (out= 2300)(deflated 55%)
# adding: org/openkoreantext/processor/util/CharArrayMap$MapEntry.class(in = 2433) (out= 1078)(deflated 55%)
# adding: org/openkoreantext/processor/util/adverb/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/adverb/adverb.txt(in = 65572) (out= 18741)(deflated 71%)
# adding: org/openkoreantext/processor/tokenizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class(in = 25564) (out= 8451)(deflated 66%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class(in = 4616) (out= 1645)(deflated 64%)
# adding: org/openkoreantext/processor/tokenizer/TokenizerProfile$.class(in = 8169) (out= 2408)(deflated 70%)
# adding: org/openkoreantext/processor/tokenizer/Sentence$.class(in = 2339) (out= 1012)(deflated 56%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer.class(in = 6968) (out= 4384)(deflated 37%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class(in = 2893) (out= 1136)(deflated 60%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunk.class(in = 5611) (out= 2907)(deflated 48%)
# adding: org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class(in = 1660) (out= 1133)(deflated 31%)
# adding: org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class(in = 9889) (out= 4174)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/ParsedChunk.class(in = 20517) (out= 8914)(deflated 56%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class(in = 2862) (out= 1067)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class(in = 1092) (out= 712)(deflated 34%)
# adding: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class(in = 3359) (out= 1497)(deflated 55%)
# adding: org/openkoreantext/processor/tokenizer/TokenizerProfile.class(in = 16403) (out= 6666)(deflated 59%)
# adding: org/openkoreantext/processor/tokenizer/ParsedChunk$.class(in = 3973) (out= 1500)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/Sentence.class(in = 5985) (out= 3125)(deflated 47%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker.class(in = 4232) (out= 2887)(deflated 31%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class(in = 6336) (out= 2633)(deflated 58%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class(in = 4043) (out= 1704)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunk$.class(in = 2361) (out= 1010)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class(in = 3459) (out= 1111)(deflated 67%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class(in = 3399) (out= 1429)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$.class(in = 17975) (out= 6790)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class(in = 3976) (out= 1402)(deflated 64%)
# adding: org/openkoreantext/processor/phrase_extractor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class(in = 37855) (out= 12404)(deflated 67%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class(in = 3358) (out= 1148)(deflated 65%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class(in = 6005) (out= 3967)(deflated 33%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class(in = 3564) (out= 1087)(deflated 69%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class(in = 6942) (out= 2591)(deflated 62%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class(in = 4857) (out= 1609)(deflated 66%)
# adding: org/openkoreantext/processor/normalizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class(in = 11553) (out= 5102)(deflated 55%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class(in = 2577) (out= 989)(deflated 61%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer.class(in = 2980) (out= 2181)(deflated 26%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class(in = 3470) (out= 1422)(deflated 59%)
# adding: org/openkoreantext/processor/qa/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets.class(in = 2720) (out= 2031)(deflated 25%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class(in = 3080) (out= 1338)(deflated 56%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class(in = 8751) (out= 3532)(deflated 59%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class(in = 3153) (out= 1446)(deflated 54%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$.class(in = 10867) (out= 4401)(deflated 59%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class(in = 2376) (out= 952)(deflated 59%)
# adding: org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class(in = 1464) (out= 823)(deflated 43%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns.class(in = 2307) (out= 1702)(deflated 26%)
# adding: org/openkoreantext/processor/qa/KoreanProcessorSandbox.class(in = 824) (out= 575)(deflated 30%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class(in = 2418) (out= 1015)(deflated 58%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor.class(in = 4428) (out= 1997)(deflated 54%)
# adding: org/openkoreantext/processor/KoreanPosJava.class(in = 2457) (out= 1241)(deflated 49%)
# adding: org/openkoreantext/processor/KoreanTokenJava.class(in = 1976) (out= 931)(deflated 52%)

# %% [markdown]
# ### 세션 다시시작하기

# %% [markdown]
# ## 호출 및 .sav 로딩

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import pickle
import json
import uvicorn
from pyngrok import ngrok
from fastapi.middleware.cors import CORSMiddleware
import nest_asyncio
from typing import List

import re
from konlpy.tag import Okt
from collections import namedtuple

# lovit 라이브러리에서 필요한 모듈 호출
from textrank import KeysentenceSummarizer

# %%
app = FastAPI()

# %%
origins = ["*"]

app.add_middleware(
    CORSMiddleware,
    allow_origins=origins,
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# %%
class model_input(BaseModel):
  title: str
  content: str

# %% [markdown]
# **호출 전 stopword_list를 업로드해줘야함**
# - 일단 배포 확인하고 이 stopword_lsit를 코드 안에 넣어줄 수 있을지 확인

# %%
'''import os
os.chdir("content")
os.getcwd()'''

import os
os.chdir("/content")
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# - 오히려 pickle하니 에러남 (??) 의존성 정리해서 코드로 넣고 배포해봄

# %%
# Summarizer_noti.sav를 summarizer_model로 로딩
summarizer_model = pickle.load(open('Summarizer_noti.sav','rb'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-55a0d0df4c8e> in <cell line: 2>()
#       1 # Summarizer_noti.sav를 summarizer_model로 로딩
# ----> 2 summarizer_model = pickle.load(open('Summarizer_noti.sav','rb'))
#
# AttributeError: Can't get attribute 'Summarizer' on <module '__main__'>

# %%
# okt 등 이슈로 다시 pickle
summarizer_model = pickle.load(open('summarizer.pkl','rb'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-1f63c8311b40> in <cell line: 2>()
#       1 # okt 등 이슈로 다시 pickle
# ----> 2 summarizer_model = pickle.load(open('summarizer.pkl','rb'))
#
# AttributeError: Can't get attribute 'Summarizer' on <module '__main__'>

# %%
# 수연님 sav 로드해보기
summarizer_model = pickle.load(open('sy_summarize_notice.sav','rb'))

# %%
class Summarizer:
    def __init__(self, stopwords_path: str, initialize: bool = True):
        self.stopwords = self.load_stopwords(stopwords_path)
        self.okt = None
        self.summarizer = None
        if initialize:
            self.initialize_components()

    def initialize_components(self):
        self.okt = Okt()
        self.summarizer = KeysentenceSummarizer(tokenize=self.okt_tokenize, min_sim=0.3)

    def load_stopwords(self, stopwords_path: str) -> List[str]:
        with open(stopwords_path, 'r') as f:
            stopwords = [line.strip() for line in f]
        return stopwords

    def okt_tokenize(self, sent: str) -> List[str]:
        words = self.okt.pos(sent, join=True)
        words = [w for w in words if ('/Noun' in w or '/Adjective' in w or '/Verb' in w)]
        return [word for word in words if word not in self.stopwords]

    def is_foreign(self, text: str, korean_threshold: float = 0.3) -> bool:
        if isinstance(text, list):
            text = ' '.join(text)

        text = text.strip()
        if not text:
            return False

        total_chars = len(text)
        korean_chars = len(re.findall('[가-힣]', text))

        return korean_chars / total_chars < korean_threshold

    def summarize_content(self, title: str, content: str) -> List[str]:
        if self.is_foreign(content):
            return []

        if not content:
            return []

        if isinstance(content, list):
            content = ' '.join(content)

        if not content.strip():
            return []

        sents = re.split(r'\n|\.', content)
        sents = list(filter(None, sents))
        sents = [sent for sent in sents if sent.strip()]

        if not sents:
            return []

        if len(sents) < 4:
            return sents

        try:
            keysents = self.summarizer.summarize(sents, topk=3)
        except ValueError as e:
            error_sent = "자세한 내용은 본문을 참고하세요."
            return [error_sent]

        return [item[2] for item in keysents]

# %% [markdown]
# ## 배포

# %%
@app.post("/summarize/")
def summarize_content(input_data:model_input):
    # 클라이언트가 전송한 데이터에서 제목과 내용을 가져옴
    title = input_data.title
    content = input_data.content

    # Summarizer 클래스를 사용하여 내용을 요약
    summary = summarizer.summarize_content(title, content)

    # 요약된 내용을 응답으로 반환
    return {"summary": summary}

# %%
get_ipython().system_raw('./ngrok http 8000 &')

# %%
# !ngrok authtoken "2hJQt9L0vTO3rTjHv0gOH43TmCf_7HG3wrTF235UCccmCQoBj"
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# ### 연결은 됨. 다만 pydantic 필요

# %%
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# Public URL: https://196f-34-125-87-89.ngrok-free.app
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a1a31a32c385> in <cell line: 3>()
#       1 ngrok_tunnel = ngrok.connect(8000)
#       2 print('Public URL:', ngrok_tunnel.public_url)
# ----> 3 nest_asyncio.apply()
#       4 uvicorn.run(app, port=8000)
#
# NameError: name 'nest_asyncio' is not defined

# %%
#authentic어쩌고 오류날 때
#!pkill ngrok

# %% [markdown]
# ### 서버사이드 설정

# %%
from fastapi import FastAPI
#from summarizer import Summarizer

app = FastAPI()

# Summarizer 초기화
summarizer = Summarizer(stopwords_path='stopwords_list.txt')

@app.post('/summarize/')
async def summarize_content(title: str, content: str):
    # Summarizer 실행
    summarized_content = summarizer.summarize_content(title, content)

    # 요약 결과 반환
    return {'summarized_content': summarized_content}

# %%
#!pip install pyngrok
from pyngrok import ngrok

# ngrok을 사용하여 로컬 서버를 외부에 공개
public_url = ngrok.connect(port='8000')
print(f'Public URL: {public_url}')
# Out:
# WARNING:pyngrok.process.ngrok:t=2024-06-07T00:36:08+0000 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=5aa0d39eaf6802f3 err="yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     517     try:
# --> 518         response = urlopen(request, encoded_data, timeout)
#     519         response_data = response.read().decode("utf-8")
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     524             meth = getattr(processor, meth_name)
# --> 525             response = meth(req, response)
#     526
#
# /usr/lib/python3.10/urllib/request.py in http_response(self, request, response)
#     633         if not (200 <= code < 300):
# --> 634             response = self.parent.error(
#     635                 'http', request, response, code, msg, hdrs)
#
# /usr/lib/python3.10/urllib/request.py in error(self, proto, *args)
#     562             args = (dict, 'default', 'http_error_default') + orig_args
# --> 563             return self._call_chain(*args)
#     564
#
# /usr/lib/python3.10/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     495             func = getattr(handler, meth_name)
# --> 496             result = func(*args)
#     497             if result is not None:
#
# /usr/lib/python3.10/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     642     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     644
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokHTTPError                     Traceback (most recent call last)
# <ipython-input-6-d2fb3eb0cfee> in <cell line: 5>()
#       3
#       4 # ngrok을 사용하여 로컬 서버를 외부에 공개
# ----> 5 public_url = ngrok.connect(port='8000')
#       6 print(f'Public URL: {public_url}')
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     318     logger.debug(f"Creating tunnel with options: {options}")
#     319
# --> 320     tunnel = NgrokTunnel(api_request(f"{api_url}/api/tunnels", method="POST", data=options,
#     321                                      timeout=pyngrok_config.request_timeout),
#     322                          pyngrok_config, api_url)
#
# /usr/local/lib/python3.10/dist-packages/pyngrok/ngrok.py in api_request(url, method, data, params, timeout, auth)
#     537         logger.debug(f"Response {status_code}: {response_data.strip()}")
#     538
# --> 539         raise PyngrokNgrokHTTPError(f"ngrok client exception, API returned {status_code}: {response_data}",
#     540                                     e.url,
#     541                                     status_code, e.reason, e.headers, response_data)
#
# PyngrokNgrokHTTPError: ngrok client exception, API returned 400: {"error_code":102,"status_code":400,"msg":"invalid tunnel configuration","details":{"err":"yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"}}

# %% [markdown]
# # 전달용 + Rouge (0609~)

# %% [markdown]
# ## 의존성 설치

# %%
# !pip install fastapi
# !pip install uvicorn
# !pip install pickle5
# !pip install pydantic
# !pip install scikit-learn
# !pip install requests
# !pip install pypi-json
# !pip install pyngrok
# !pip install nest-asyncio

# lovit 가져오기
# 패키지
# !pip install git+https://github.com/lovit/textrank.git
# 깃 클론
# !git clone https://github.com/lovit/textrank.git
# Out:
# Collecting fastapi
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 723.6 kB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.7.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.2)
# Collecting fastapi-cli>=0.0.2 (from fastapi)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting httpx>=0.23.0 (from fastapi)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 1.7 MB/s eta 0:00:00
# Collecting orjson>=3.2.1 (from fastapi)
#   Downloading orjson-3.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 1.8 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi)
#   Downloading email_validator-2.1.1-py3-none-any.whl (30 kB)
# Collecting uvicorn[standard]>=0.12.0 (from fastapi)
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 3.0 MB/s eta 0:00:00
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi) (3.7)
# Requirement already satisfied: typer>=0.12.3 in /usr/local/lib/python3.10/dist-packages (from fastapi-cli>=0.0.2->fastapi) (0.12.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.23.0->fastapi)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastapi) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.23.0->fastapi)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi) (2.1.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.18.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi) (8.1.7)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 14.5 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.12.0->fastapi) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 19.7 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.7 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0->fastapi)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.23.0->fastapi) (1.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.12.3->fastapi-cli>=0.0.2->fastapi) (0.1.2)
# Installing collected packages: websockets, uvloop, ujson, python-multipart, python-dotenv, orjson, httptools, h11, dnspython, watchfiles, uvicorn, starlette, httpcore, email_validator, httpx, fastapi-cli, fastapi
# Successfully installed dnspython-2.6.1 email_validator-2.1.1 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 orjson-3.10.4 python-dotenv-1.0.1 python-multipart-0.0.9 starlette-0.37.2 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (0.30.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: typing-extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (4.12.2)
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py) ... done
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255313 sha256=22758179e5c378af13b4797f1f7b0cac7de72a633bfb1367e381f8edbc7a26c6
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (2.7.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic) (4.12.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)
# Collecting pypi-json
#   Downloading pypi_json-0.4.0-py3-none-any.whl (26 kB)
# Collecting apeye>=1.1.0 (from pypi-json)
#   Downloading apeye-1.4.1-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.0/108.0 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.10/dist-packages (from pypi-json) (24.1)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from pypi-json) (2.31.0)
# Collecting apeye-core>=1.0.0b2 (from apeye>=1.1.0->pypi-json)
#   Downloading apeye_core-1.1.5-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.3/99.3 kB 6.2 MB/s eta 0:00:00
# Collecting domdf-python-tools>=2.6.0 (from apeye>=1.1.0->pypi-json)
#   Downloading domdf_python_tools-3.8.1-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from apeye>=1.1.0->pypi-json) (4.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->pypi-json) (2024.6.2)
# Requirement already satisfied: natsort>=7.0.1 in /usr/local/lib/python3.10/dist-packages (from domdf-python-tools>=2.6.0->apeye>=1.1.0->pypi-json) (8.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from domdf-python-tools>=2.6.0->apeye>=1.1.0->pypi-json) (4.12.2)
# Installing collected packages: domdf-python-tools, apeye-core, apeye, pypi-json
# Successfully installed apeye-1.4.1 apeye-core-1.1.5 domdf-python-tools-3.8.1 pypi-json-0.4.0
# Collecting pyngrok
#   Downloading pyngrok-7.1.6-py3-none-any.whl (22 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.1)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.1.6
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Collecting git+https://github.com/lovit/textrank.git
#   Cloning https://github.com/lovit/textrank.git to /tmp/pip-req-build-2qut6njh
#   Running command git clone --filter=blob:none --quiet https://github.com/lovit/textrank.git /tmp/pip-req-build-2qut6njh
#   Resolved https://github.com/lovit/textrank.git to commit 578c7fbbb22b24561b1bd4bab9a9ecc2dc9515e1
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: textrank
#   Building wheel for textrank (setup.py) ... done
#   Created wheel for textrank: filename=textrank-0.1.2-py3-none-any.whl size=11142 sha256=c4be091f873b6ff18ed52a1afce0563fd1480f932b2e96f89e9870abebc6ae1f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_o700fln/wheels/8d/d1/ef/7c6abc0d5bbb64f01bd86b0ad967911d4b7f21bb44813b3239
# Successfully built textrank
# Installing collected packages: textrank
# Successfully installed textrank-0.1.2
# Cloning into 'textrank'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 232 (delta 1), reused 1 (delta 0), pack-reused 225
# Receiving objects: 100% (232/232), 1.21 MiB | 7.14 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %% [markdown]
# ### konlpy 사용자 사전

# %%
#konlpy가져오기
#konlpy 다운 및 호출
#1. Konlpy에서 Okt
# !pip install konlpy
#2. konlpy 실행을 위한 자바어쩌구 다운
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#3. 필요한 설정
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
from konlpy.tag import Okt
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 46.8 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 38.8 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %%
# 사용자 사전 찾아가기 및 경로 설정 _ 여기서 오류가 날 시 코랩에서 폴더 열어서 usr,local 찾아가보시며 폴더명이 일치하는지 확인해보세요! 보통 파이썬 버전이 다릅니다.
os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java')
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages/konlpy/java'

# %%
#jar파일을 풀어줄 폴더이름을 정합니다. 저는 temp_fix로 했어요!
os.makedirs('./temp_fix')
os.chdir('./temp_fix')
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix'

# %%
#inflated어쩌고 쭉뜨고 맨끝에 에러 없으면 잘된겁니다!
# !jar xvf ../open-korean-text-2.1.0.jar
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#   created: org/openkoreantext/processor/normalizer/
#   created: org/openkoreantext/processor/phrase_extractor/
#   created: org/openkoreantext/processor/qa/
#   created: org/openkoreantext/processor/stemmer/
#   created: org/openkoreantext/processor/tokenizer/
#   created: org/openkoreantext/processor/tools/
#   created: org/openkoreantext/processor/util/
#   created: org/openkoreantext/processor/util/adjective/
#   created: org/openkoreantext/processor/util/adverb/
#   created: org/openkoreantext/processor/util/auxiliary/
#   created: org/openkoreantext/processor/util/freq/
#   created: org/openkoreantext/processor/util/josa/
#   created: org/openkoreantext/processor/util/noun/
#   created: org/openkoreantext/processor/util/substantives/
#   created: org/openkoreantext/processor/util/typos/
#   created: org/openkoreantext/processor/util/verb/
#  inflated: org/openkoreantext/processor/KoreanPosJava.class
#  inflated: org/openkoreantext/processor/KoreanTokenJava.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class
#  inflated: org/openkoreantext/processor/normalizer/KoreanNormalizer.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor$.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessor.class
#  inflated: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class
#  inflated: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class
#  inflated: org/openkoreantext/processor/qa/BatchGetUnknownNouns.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class
#  inflated: org/openkoreantext/processor/qa/BatchTokenizeTweets.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class
#  inflated: org/openkoreantext/processor/qa/KoreanProcessorSandbox.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer$.class
#  inflated: org/openkoreantext/processor/stemmer/KoreanStemmer.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanChunker.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class
#  inflated: org/openkoreantext/processor/tokenizer/KoreanTokenizer.class
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk$.class
#  inflated: org/openkoreantext/processor/tokenizer/ParsedChunk.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence$.class
#  inflated: org/openkoreantext/processor/tokenizer/Sentence.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile$.class
#  inflated: org/openkoreantext/processor/tokenizer/TokenizerProfile.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class
#  inflated: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class
#  inflated: org/openkoreantext/processor/tools/CreateConjugationExamples.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class
#  inflated: org/openkoreantext/processor/tools/CreateParsingExamples.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class
#  inflated: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class
#  inflated: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class
#  inflated: org/openkoreantext/processor/tools/Runnable.class
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples$.class
#  inflated: org/openkoreantext/processor/tools/UpdateAllTheExamples.class
#  inflated: org/openkoreantext/processor/util/adjective/adjective.txt
#  inflated: org/openkoreantext/processor/util/adverb/adverb.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/conjunctions.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/determiner.txt
#  inflated: org/openkoreantext/processor/util/auxiliary/exclamation.txt
#  inflated: org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharacterUtils.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$1.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$MapEntry.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArrayMap.class
#  inflated: org/openkoreantext/processor/util/CharArraySet.class
#  inflated: org/openkoreantext/processor/util/example_chunks.txt
#  inflated: org/openkoreantext/processor/util/example_tweets.txt
#  inflated: org/openkoreantext/processor/util/freq/entity-freq.txt.gz
#  inflated: org/openkoreantext/processor/util/Hangul$.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda$.class
#  inflated: org/openkoreantext/processor/util/Hangul$DoubleCoda.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar$.class
#  inflated: org/openkoreantext/processor/util/Hangul$HangulChar.class
#  inflated: org/openkoreantext/processor/util/Hangul.class
#  inflated: org/openkoreantext/processor/util/josa/josa.txt
#  inflated: org/openkoreantext/processor/util/KoreanConjugation$.class
#  inflated: org/openkoreantext/processor/util/KoreanConjugation.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider$.class
#  inflated: org/openkoreantext/processor/util/KoreanDictionaryProvider.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class
#  inflated: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class
#  inflated: org/openkoreantext/processor/util/KoreanPos.class
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive$.class
#  inflated: org/openkoreantext/processor/util/KoreanSubstantive.class
#  inflated: org/openkoreantext/processor/util/noun/bible.txt
#  inflated: org/openkoreantext/processor/util/noun/company_names.txt
#  inflated: org/openkoreantext/processor/util/noun/congress.txt
#  inflated: org/openkoreantext/processor/util/noun/entities.txt
#  inflated: org/openkoreantext/processor/util/noun/foreign.txt
#  inflated: org/openkoreantext/processor/util/noun/geolocations.txt
#  inflated: org/openkoreantext/processor/util/noun/kpop.txt
#  inflated: org/openkoreantext/processor/util/noun/lol.txt
#  inflated: org/openkoreantext/processor/util/noun/names.txt
#  inflated: org/openkoreantext/processor/util/noun/nouns.txt
#  inflated: org/openkoreantext/processor/util/noun/pokemon.txt
#  inflated: org/openkoreantext/processor/util/noun/profane.txt
#  inflated: org/openkoreantext/processor/util/noun/slangs.txt
#  inflated: org/openkoreantext/processor/util/noun/spam.txt
#  inflated: org/openkoreantext/processor/util/noun/twitter.txt
#  inflated: org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt
#  inflated: org/openkoreantext/processor/util/substantives/family_names.txt
#  inflated: org/openkoreantext/processor/util/substantives/given_names.txt
#  inflated: org/openkoreantext/processor/util/substantives/modifier.txt
#  inflated: org/openkoreantext/processor/util/substantives/suffix.txt
#  inflated: org/openkoreantext/processor/util/typos/typos.txt
#  inflated: org/openkoreantext/processor/util/verb/eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/pre_eomi.txt
#  inflated: org/openkoreantext/processor/util/verb/verb.txt
#  inflated: org/openkoreantext/processor/util/verb/verb_prefix.txt
#   created: META-INF/maven/
#   created: META-INF/maven/org.openkoreantext/
#   created: META-INF/maven/org.openkoreantext/open-korean-text/
#  inflated: META-INF/maven/org.openkoreantext/open-korean-text/pom.xml
#  inflated: META-INF/maven/org.openkoreantext/open-korean-text/pom.properties

# %%
# 사용자 사전 열기
with open(f"/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()

# %%
#gongji
data += "한국외국어대학교\n한국외대\n안내\종합정보시스템\공고\n이수\n학기\n대하여\n아래\n수강편람\n이중전공\n수강신청함\n수강신청\n예비수강신청\n교무처장\n수강료\n등록기간\n수강신청자\n한하다\n미수강신청자\n납부불가\n핫링크\n고지서출력\n가상계좌\n붙임파일\n모바일앱\n내역\n인터넷뱅킹\n텔레뱅킹\n개시일\n신청\n마감\n마감일\n수강취소\n수강변경\종합정보화면\n계절학기\n부분환불\n계절학기\학년도\n접수일\n학석사\n학사\n석사\n연계\n과정생\n접수처\n학사종합지원센터\n양캠퍼스\n통번역\n이수\n미배정\n부전공\여석\n이수\n지원\n학사종합지원센터\n한국예술종합학교\n특성화\n수강편람\n실용외국어\n공동교양\n여석\졸업\n사정\n결과\n확정자\n불가자\n개강일\n우리대학교\n우리대학\n안내문\n학위\n학위증\n코로나바이러스\n신종코로나바이러스\nHUFS\n양캠퍼스\n서울캠퍼스\n글로벌캠퍼스\n서울글로벌캠퍼스\n서울·글로벌캠퍼스\n우리은행\n단과대학\n졸업시험\n논문\n제적\n졸업요건\n지역학사\n지역전문가과정\n수료졸업대기\nELLT학과\n영어학과\n아랍어과\n미디어커뮤니케이션학부\n영어전공\n영미문학문화학과\n태국어과\n경제학부\nEICC학과\n영어통번역학과\n베트남어과\n국제통상학과\이란어과\n경영학부\n프랑스어학부\n인도어과\n영어교육과\n독일어과\n터키아제르바이잔어과\n프랑스어교육과\n노어과\n몽골어과\n독일어교육과\n스페인어과\n중국언어문화학부\n한국어교육과\n이탈리아어과\n중국외교통상학부\n국제학부\n포르투갈어과\n그리스불가리아학과\n일본언어문화학부\n사회과학전공\n네덜란드어과\n융합일본지역학부\nLD전공\n스칸디나비아어과\n정치외교학과\nLT전공\n말레이인도네시아어과\n행정학과\n서양어대학\n아시아언어문화대학\n중국어대학\n일본어대학\n사회과학\n상경\n경영\n국제학부\n사회과학전공\n사범대학\n교직\
 홈페이지\n채용시스템\n공고문\n바로가기 배너\n피성년후견인\n금고 이상의 형\n병역기피자\n신체검사결과\n부적당\n부적합\n기재내용\n허위 사실\n허위사실\n기타 문의\n인사팀\n행정지원처장\n전임강사\n채용분야\n인원\n한국어문화교육원\n전임강사\n외국어로서의한국어교육\n공통지원자격\n사업본부\n임용기준\n성 관련 범죄\n박사학위\n외국어로서의 한국어교육전공\n부속기관\한국어교원자격증\n자격증\n발행기관\n책임시간\n서울캠퍼스\n채용일\n추후 협의\n증빙서류\n제출목록\n지원서\n온라인지원\n졸업증명서\n성적증명서\n학사\n석사\n박사\n업로드\n성범죄 경력조회서\n경력증명서\n발급본\n지원 기간\n접수 방법\n사업본부\n개별 통보\n개별 통지\n연구보조원\n숙련자\n웹페이지\nKMOOC\n인문사회계열\n전형방법\n서류전형\n면접대상자\n줌주소\n실습데이터\nZOOM데스크탑앱\n포트폴리오\n지원서 접수\n압축파일\nzip\n학생상담센터\n개인상담\n집단상담\n대학혁신지원사업\n상담센터\n석사학위\n소지자\n경력(재직)증명서\n개인정보동의서\n별첨양식\n교직원 출퇴근 셔틀버스\n출퇴근\n교직원\n이문동\n잠실\n분당\n노선\n오피스\n스페인어\n포르투갈어\n석사\n재학생\nHK연구소\n중남미연구소\n내부규정\n급여\n계약기간\n교내외장학금\n사회 배려계층\n교무행정팀\n객원상담원\n겸임교수\n초빙교수\n초빙공고\n정보통신공학과\n재공고\n시설관리팀\n수목관리\n직원인사규정\n제11조\n임용결격사유\n1종보통 운전면허\n외국인학생\n여름방학\n민원응대\n봉사장학금\n장학금지급규정\n등록금 범위내\n국제학사\nGlobeeDorm\n학사운영팀\n중국연구소\n전임연구원\n최종학위증명서\n이력서\n자율양식\n경력증명서\n채용예정일\n지식출판콘텐츠원\n채용공고\n경영기획팀\n행정\n학사학위\n국고사업\n관련법\n연구산학협력단\n러시아연구소\n초빙분야\n세부전공\n인센티브\n4대 보험\n한국연구재단\n인문한국플로스지원사업\n사립학교\n해당 분야\n기초심사\n전공면접\n경기도 용인시 처인구 모현면 외대로 81\n국제사회교육원\n러시아연구소\n육아휴직\n학술정보팀\n퇴직금\nTESOL\nFLEX센터\n능숙자\nOA프로그램\n영어회화\n관련업무\n유경험자\n근무 가능자\근무 가능\n장학생\n재학생\n언어 능력\n설명회\n선착순\n국제입학관리팀\n"

# %%
# 파일 새롭게 저장
with open("/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)
# !jar cvf ../open-korean-text-2.1.0.jar *
# Out:
# added manifest
# ignoring entry META-INF/
# adding: META-INF/maven/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.xml(in = 9127) (out= 2208)(deflated 75%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.properties(in = 119) (out= 110)(deflated 7%)
# ignoring entry META-INF/MANIFEST.MF
# adding: org/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/qa/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets.class(in = 2720) (out= 2031)(deflated 25%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet$.class(in = 2376) (out= 952)(deflated 59%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime$.class(in = 2418) (out= 1015)(deflated 58%)
# adding: org/openkoreantext/processor/qa/KoreanProcessorSandbox$.class(in = 1464) (out= 823)(deflated 43%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$.class(in = 8751) (out= 3532)(deflated 59%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns.class(in = 2307) (out= 1702)(deflated 26%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$.class(in = 10867) (out= 4401)(deflated 59%)
# adding: org/openkoreantext/processor/qa/BatchGetUnknownNouns$ChunkWithTweet.class(in = 3080) (out= 1338)(deflated 56%)
# adding: org/openkoreantext/processor/qa/KoreanProcessorSandbox.class(in = 824) (out= 575)(deflated 30%)
# adding: org/openkoreantext/processor/qa/BatchTokenizeTweets$ParseTime.class(in = 3153) (out= 1446)(deflated 54%)
# adding: org/openkoreantext/processor/tokenizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunk.class(in = 5611) (out= 2907)(deflated 48%)
# adding: org/openkoreantext/processor/tokenizer/ParsedChunk$.class(in = 3973) (out= 1500)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/KoreanDetokenizer.class(in = 1660) (out= 1133)(deflated 31%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken$.class(in = 3976) (out= 1402)(deflated 64%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunk$.class(in = 2361) (out= 1010)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter$.class(in = 3359) (out= 1497)(deflated 55%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse$.class(in = 3459) (out= 1111)(deflated 67%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch$.class(in = 2893) (out= 1136)(deflated 60%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$.class(in = 25564) (out= 8451)(deflated 66%)
# adding: org/openkoreantext/processor/tokenizer/ParsedChunk.class(in = 20517) (out= 8914)(deflated 56%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker.class(in = 4232) (out= 2887)(deflated 31%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$CandidateParse.class(in = 4616) (out= 1645)(deflated 64%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$ChunkMatch.class(in = 4043) (out= 1704)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/Sentence.class(in = 5985) (out= 3125)(deflated 47%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie$.class(in = 2862) (out= 1067)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/Sentence$.class(in = 2339) (out= 1012)(deflated 56%)
# adding: org/openkoreantext/processor/tokenizer/TokenizerProfile.class(in = 16403) (out= 6666)(deflated 59%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$PossibleTrie.class(in = 3399) (out= 1429)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanChunker$.class(in = 17975) (out= 6790)(deflated 62%)
# adding: org/openkoreantext/processor/tokenizer/TokenizerProfile$.class(in = 8169) (out= 2408)(deflated 70%)
# adding: org/openkoreantext/processor/tokenizer/KoreanDetokenizer$.class(in = 9889) (out= 4174)(deflated 57%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer$KoreanToken.class(in = 6336) (out= 2633)(deflated 58%)
# adding: org/openkoreantext/processor/tokenizer/KoreanSentenceSplitter.class(in = 1092) (out= 712)(deflated 34%)
# adding: org/openkoreantext/processor/tokenizer/KoreanTokenizer.class(in = 6968) (out= 4384)(deflated 37%)
# adding: org/openkoreantext/processor/stemmer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/stemmer/KoreanStemmer.class(in = 1439) (out= 972)(deflated 32%)
# adding: org/openkoreantext/processor/stemmer/KoreanStemmer$.class(in = 7044) (out= 2892)(deflated 58%)
# adding: org/openkoreantext/processor/KoreanPosJava.class(in = 2457) (out= 1241)(deflated 49%)
# adding: org/openkoreantext/processor/tools/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/tools/Runnable.class(in = 964) (out= 694)(deflated 28%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples.class(in = 2427) (out= 1732)(deflated 28%)
# adding: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class(in = 833) (out= 566)(deflated 32%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class(in = 3825) (out= 1443)(deflated 62%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$.class(in = 5517) (out= 2327)(deflated 57%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples.class(in = 2367) (out= 1659)(deflated 29%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample.class(in = 3718) (out= 1429)(deflated 61%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample$.class(in = 2974) (out= 1020)(deflated 65%)
# adding: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class(in = 7154) (out= 3133)(deflated 56%)
# adding: org/openkoreantext/processor/tools/CreateParsingExamples$ParsingExample$.class(in = 2842) (out= 1010)(deflated 64%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample$.class(in = 2787) (out= 997)(deflated 64%)
# adding: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class(in = 5487) (out= 2305)(deflated 57%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class(in = 3569) (out= 1415)(deflated 60%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples.class(in = 2516) (out= 1784)(deflated 29%)
# adding: org/openkoreantext/processor/tools/UpdateAllTheExamples$.class(in = 4383) (out= 1794)(deflated 59%)
# adding: org/openkoreantext/processor/tools/CreateConjugationExamples$.class(in = 5881) (out= 2385)(deflated 59%)
# adding: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class(in = 5989) (out= 2472)(deflated 58%)
# adding: org/openkoreantext/processor/tools/UpdateAllTheExamples.class(in = 1089) (out= 756)(deflated 30%)
# adding: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries.class(in = 1117) (out= 823)(deflated 26%)
# adding: org/openkoreantext/processor/util/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/Hangul$.class(in = 7625) (out= 3114)(deflated 59%)
# adding: org/openkoreantext/processor/util/CharacterUtils$CharacterBuffer.class(in = 1634) (out= 659)(deflated 59%)
# adding: org/openkoreantext/processor/util/KoreanSubstantive$.class(in = 14990) (out= 6195)(deflated 58%)
# adding: org/openkoreantext/processor/util/auxiliary/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/auxiliary/determiner.txt(in = 63) (out= 63)(deflated 0%)
# adding: org/openkoreantext/processor/util/auxiliary/exclamation.txt(in = 1759) (out= 757)(deflated 56%)
# adding: org/openkoreantext/processor/util/auxiliary/conjunctions.txt(in = 398) (out= 189)(deflated 52%)
# adding: org/openkoreantext/processor/util/CharacterUtils$Java5CharacterUtils.class(in = 2824) (out= 1393)(deflated 50%)
# adding: org/openkoreantext/processor/util/substantives/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/substantives/family_names.txt(in = 299) (out= 197)(deflated 34%)
# adding: org/openkoreantext/processor/util/substantives/modifier.txt(in = 3395) (out= 1346)(deflated 60%)
# adding: org/openkoreantext/processor/util/substantives/given_names.txt(in = 1407) (out= 609)(deflated 56%)
# adding: org/openkoreantext/processor/util/substantives/suffix.txt(in = 325) (out= 224)(deflated 31%)
# adding: org/openkoreantext/processor/util/CharArrayMap$UnmodifiableCharArrayMap.class(in = 3062) (out= 859)(deflated 71%)
# adding: org/openkoreantext/processor/util/Hangul$HangulChar$.class(in = 2389) (out= 1022)(deflated 57%)
# adding: org/openkoreantext/processor/util/CharArrayMap.class(in = 11923) (out= 4878)(deflated 59%)
# adding: org/openkoreantext/processor/util/KoreanConjugation$.class(in = 22440) (out= 7972)(deflated 64%)
# adding: org/openkoreantext/processor/util/CharacterUtils.class(in = 3703) (out= 1716)(deflated 53%)
# adding: org/openkoreantext/processor/util/typos/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/typos/typos.txt(in = 5146) (out= 2300)(deflated 55%)
# adding: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie.class(in = 4390) (out= 1610)(deflated 63%)
# adding: org/openkoreantext/processor/util/Hangul.class(in = 3981) (out= 2731)(deflated 31%)
# adding: org/openkoreantext/processor/util/KoreanDictionaryProvider.class(in = 3430) (out= 2003)(deflated 41%)
# adding: org/openkoreantext/processor/util/Hangul$DoubleCoda.class(in = 2930) (out= 1348)(deflated 53%)
# adding: org/openkoreantext/processor/util/KoreanSubstantive.class(in = 1336) (out= 1087)(deflated 18%)
# adding: org/openkoreantext/processor/util/KoreanPos$KoreanPosTrie$.class(in = 3157) (out= 1089)(deflated 65%)
# adding: org/openkoreantext/processor/util/KoreanConjugation.class(in = 1550) (out= 1237)(deflated 20%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EmptyCharArrayMap.class(in = 2053) (out= 725)(deflated 64%)
# adding: org/openkoreantext/processor/util/KoreanPos.class(in = 6890) (out= 3877)(deflated 43%)
# adding: org/openkoreantext/processor/util/CharArraySet.class(in = 4886) (out= 1944)(deflated 60%)
# adding: org/openkoreantext/processor/util/josa/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/josa/josa.txt(in = 5219) (out= 1476)(deflated 71%)
# adding: org/openkoreantext/processor/util/freq/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/freq/entity-freq.txt.gz(in = 385753) (out= 385873)(deflated 0%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EntrySet.class(in = 2788) (out= 1181)(deflated 57%)
# adding: org/openkoreantext/processor/util/example_tweets.txt(in = 86271) (out= 38336)(deflated 55%)
# adding: org/openkoreantext/processor/util/Hangul$DoubleCoda$.class(in = 2155) (out= 963)(deflated 55%)
# adding: org/openkoreantext/processor/util/CharArrayMap$1.class(in = 1531) (out= 571)(deflated 62%)
# adding: org/openkoreantext/processor/util/KoreanDictionaryProvider$.class(in = 20197) (out= 7488)(deflated 62%)
# adding: org/openkoreantext/processor/util/verb/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/verb/eomi.txt(in = 12618) (out= 3556)(deflated 71%)
# adding: org/openkoreantext/processor/util/verb/verb.txt(in = 32758) (out= 10723)(deflated 67%)
# adding: org/openkoreantext/processor/util/verb/pre_eomi.txt(in = 285) (out= 185)(deflated 35%)
# adding: org/openkoreantext/processor/util/verb/verb_prefix.txt(in = 47) (out= 52)(deflated -10%)
# adding: org/openkoreantext/processor/util/adverb/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/adverb/adverb.txt(in = 65572) (out= 18741)(deflated 71%)
# adding: org/openkoreantext/processor/util/Hangul$HangulChar.class(in = 3185) (out= 1421)(deflated 55%)
# adding: org/openkoreantext/processor/util/KoreanPos$.class(in = 12173) (out= 4669)(deflated 61%)
# adding: org/openkoreantext/processor/util/CharArrayMap$MapEntry.class(in = 2433) (out= 1078)(deflated 55%)
# adding: org/openkoreantext/processor/util/example_chunks.txt(in = 522978) (out= 163253)(deflated 68%)
# adding: org/openkoreantext/processor/util/noun/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/noun/nouns.txt(in = 219319) (out= 84134)(deflated 61%)
# adding: org/openkoreantext/processor/util/noun/geolocations.txt(in = 5423) (out= 2267)(deflated 58%)
# adding: org/openkoreantext/processor/util/noun/wikipedia_title_nouns.txt(in = 1971964) (out= 686708)(deflated 65%)
# adding: org/openkoreantext/processor/util/noun/twitter.txt(in = 254) (out= 162)(deflated 36%)
# adding: org/openkoreantext/processor/util/noun/profane.txt(in = 569) (out= 337)(deflated 40%)
# adding: org/openkoreantext/processor/util/noun/names.txt(in = 21485) (out= 6439)(deflated 70%)
# adding: org/openkoreantext/processor/util/noun/slangs.txt(in = 1565) (out= 921)(deflated 41%)
# adding: org/openkoreantext/processor/util/noun/lol.txt(in = 1337) (out= 744)(deflated 44%)
# adding: org/openkoreantext/processor/util/noun/congress.txt(in = 26494) (out= 9351)(deflated 64%)
# adding: org/openkoreantext/processor/util/noun/pokemon.txt(in = 1781) (out= 965)(deflated 45%)
# adding: org/openkoreantext/processor/util/noun/foreign.txt(in = 10485) (out= 4686)(deflated 55%)
# adding: org/openkoreantext/processor/util/noun/company_names.txt(in = 1631) (out= 905)(deflated 44%)
# adding: org/openkoreantext/processor/util/noun/bible.txt(in = 2032) (out= 1005)(deflated 50%)
# adding: org/openkoreantext/processor/util/noun/entities.txt(in = 108142) (out= 44095)(deflated 59%)
# adding: org/openkoreantext/processor/util/noun/spam.txt(in = 202) (out= 157)(deflated 22%)
# adding: org/openkoreantext/processor/util/noun/kpop.txt(in = 5371) (out= 2495)(deflated 53%)
# adding: org/openkoreantext/processor/util/adjective/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/util/adjective/adjective.txt(in = 27250) (out= 9357)(deflated 65%)
# adding: org/openkoreantext/processor/util/CharArrayMap$EntryIterator.class(in = 3118) (out= 1270)(deflated 59%)
# adding: org/openkoreantext/processor/util/CharacterUtils$Java4CharacterUtils.class(in = 2577) (out= 1282)(deflated 50%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor.class(in = 4428) (out= 1997)(deflated 54%)
# adding: org/openkoreantext/processor/normalizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class(in = 2577) (out= 989)(deflated 61%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$.class(in = 11553) (out= 5102)(deflated 55%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer.class(in = 2980) (out= 2181)(deflated 26%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment.class(in = 3470) (out= 1422)(deflated 59%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessorJava.class(in = 5901) (out= 1995)(deflated 66%)
# adding: org/openkoreantext/processor/phrase_extractor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$.class(in = 37855) (out= 12404)(deflated 67%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer$.class(in = 3564) (out= 1087)(deflated 69%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase.class(in = 6942) (out= 2591)(deflated 62%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor.class(in = 6005) (out= 3967)(deflated 33%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$PhraseBuffer.class(in = 4857) (out= 1609)(deflated 66%)
# adding: org/openkoreantext/processor/phrase_extractor/KoreanPhraseExtractor$KoreanPhrase$.class(in = 3358) (out= 1148)(deflated 65%)
# adding: org/openkoreantext/processor/OpenKoreanTextProcessor$.class(in = 7716) (out= 2400)(deflated 68%)
# adding: org/openkoreantext/processor/KoreanTokenJava.class(in = 1976) (out= 931)(deflated 52%)

# %% [markdown]
# ####  ======= 세션 새로 시작 ========

# %% [markdown]
# ## 함수 호출 및 클래스 로딩

# %%
from fastapi import FastAPI
# json 처리
from fastapi.encoders import jsonable_encoder
from fastapi import HTTPException
from pydantic import ValidationError

from pydantic import BaseModel
from typing import List, Union,Dict
#from konlpy.tag import Okt #상단에서 이미 완료
import re
from konlpy.tag import Okt
import jpype
from pyngrok import ngrok
import nest_asyncio
import uvicorn
from textrank import KeysentenceSummarizer
from fastapi.middleware.cors import CORSMiddleware
import json

# lovit 라이브러리에서 필요한 모듈 호출
from textrank import KeysentenceSummarizer

# %%
# 요약 클래스 선언
class Summarizer:
    def __init__(self, stopwords_path: str, initialize: bool = True):
        self.stopwords = self.load_stopwords(stopwords_path)
        self.okt = None
        self.summarizer = None
        if initialize:
            self.initialize_components()

    def initialize_components(self):
        self.okt = Okt()
        self.summarizer = KeysentenceSummarizer(tokenize=self.okt_tokenize, min_sim=0.3)

    def load_stopwords(self, stopwords_path: str) -> List[str]:
        with open(stopwords_path, 'r') as f:
            stopwords = [line.strip() for line in f]
        return stopwords

    def okt_tokenize(self, sent: str) -> List[str]:
        words = self.okt.pos(sent, join=True)
        words = [w for w in words if ('/Noun' in w or '/Adjective' in w or '/Verb' in w)]
        return [word for word in words if word not in self.stopwords]

    def is_foreign(self, text: str, korean_threshold: float = 0.3) -> bool:
        if isinstance(text, list):
            text = ' '.join(text)

        text = text.strip()
        if not text:
            return False

        total_chars = len(text)
        korean_chars = len(re.findall('[가-힣]', text))

        return korean_chars / total_chars < korean_threshold

    def summarize_content(self, title: str, content: str) -> List[str]:
        if self.is_foreign(content):
            #return []
            return "자세한 내용은 본문을 참고하세요."

        if not content:
            return []

        if isinstance(content, list):
            content = ' '.join(content)

        if not content.strip():
            return []

        # 따옴표 제거하기
        content = content.replace('"','').replace("'",'')

        sents = re.split(r'\n|\.', content)
        sents = list(filter(None, sents))
        sents = [sent for sent in sents if sent.strip()]

        if not sents:
            return []

        if len(sents) < 4:
            return sents

        try:
            keysents = self.summarizer.summarize(sents, topk=3)
        except ValueError as e:
            error_sent = "자세한 내용은 본문을 참고하세요."
            return [error_sent]

        return [item[2] for item in keysents]

# %% [markdown]
# ## FastApi

# %%
app = FastAPI()

# Summarizer 인스턴스를 생성
stopwords_path = '/content/stopwords_list.txt'  # 실제 경로로 변경해야 함
summarizer = Summarizer(stopwords_path)

# %%
class ModelInput(BaseModel):
    title: str
    content: str

@app.post("/summarize/")
def summarize_content(input_data: ModelInput):
    title = input_data.title
    content = input_data.content
    summary = summarizer.summarize_content(title, content)
    return {"summary": summary}

# %%
# json 처리용 apppost -> 서버에러가 남, 이걸로 처리 좀 애매해보임

class ModelInput(BaseModel):
    title: str
    content: str

@app.post("/summarize/")
def summarize_content(input_data: ModelInput):
    try:
        input_data.validate()  # 입력 데이터 유효성 검사
        input_json = jsonable_encoder(input_data)
        title = input_json["title"]
        content = input_json["content"]
        summary = summarizer.summarize_content(json.dumps(input_json))
        return {"summary": summary}
    except ValidationError as e:
        raise HTTPException(status_code=422, detail="자세한 내용은 본문을 참고하세요.")
    except Exception as e:
        raise HTTPException(status_code=500, detail="서버 에러가 발생했습니다.")

# %% [markdown]
# ### 배포 및 서버시작

# %%
# Colab에서 asyncio 이벤트 루프를 중첩
nest_asyncio.apply()

# ngrok 터널 시작
ngrok.kill()  # 기존 ngrok 세션 종료

# 토큰 갱신 필요시 갱신
# !ngrok authtoken "2hJQt9L0vTO3rTjHv0gOH43TmCf_7HG3wrTF235UCccmCQoBj"
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)

# Uvicorn을 사용하여 FastAPI 앱 실행
uvicorn.run(app, host='0.0.0.0', port=8000)
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Public URL: https://548a-34-45-248-145.ngrok-free.app
# INFO:     Started server process [1886]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 200 OK
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 422 Unprocessable Entity
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 422 Unprocessable Entity
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 422 Unprocessable Entity
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 422 Unprocessable Entity
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 422 Unprocessable Entity
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 422 Unprocessable Entity
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 422 Unprocessable Entity
# INFO:     117.110.95.42:0 - "POST /summarize/ HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [1886]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-9f59dd42f9b8> in <cell line: 13>()
#      11
#      12 # Uvicorn을 사용하여 FastAPI 앱 실행
# ---> 13 uvicorn.run(app, host='0.0.0.0', port=8000)
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/main.py in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     575             Multiprocess(config, target=server.run, sockets=[sock]).run()
#     576         else:
# --> 577             server.run()
#     578     finally:
#     579         if config.uds and os.path.exists(config.uds):
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in run(self, sockets)
#      63     def run(self, sockets: list[socket.socket] | None = None) -> None:
#      64         self.config.setup_event_loop()
# ---> 65         return asyncio.run(self.serve(sockets=sockets))
#      66
#      67     async def serve(self, sockets: list[socket.socket] | None = None) -> None:
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run(main, debug)
#      28         task = asyncio.ensure_future(main)
#      29         try:
# ---> 30             return loop.run_until_complete(task)
#      31         finally:
#      32             if not task.done():
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in run_until_complete(self, future)
#      90                 f._log_destroy_pending = False
#      91             while not f.done():
# ---> 92                 self._run_once()
#      93                 if self._stopping:
#      94                     break
#
# /usr/local/lib/python3.10/dist-packages/nest_asyncio.py in _run_once(self)
#     131
#     132                 try:
# --> 133                     handle._run()
#     134                 finally:
#     135                     # restore the current task
#
# /usr/lib/python3.10/asyncio/events.py in _run(self)
#      78     def _run(self):
#      79         try:
# ---> 80             self._context.run(self._callback, *self._args)
#      81         except (SystemExit, KeyboardInterrupt):
#      82             raise
#
# /usr/lib/python3.10/asyncio/tasks.py in __wakeup(self, future)
#     313             # instead of `__next__()`, which is slower for futures
#     314             # that return non-generator iterators from their `__iter__`.
# --> 315             self.__step()
#     316         self = None  # Needed to break cycles when an exception occurs.
#     317
#
# /usr/lib/python3.10/asyncio/tasks.py in __step(***failed resolving arguments***)
#     230                 # We use the `send` method directly, because coroutines
#     231                 # don't have `__iter__` and `__next__` methods.
# --> 232                 result = coro.send(None)
#     233             else:
#     234                 result = coro.throw(exc)
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in serve(self, sockets)
#      66
#      67     async def serve(self, sockets: list[socket.socket] | None = None) -> None:
# ---> 68         with self.capture_signals():
#      69             await self._serve(sockets)
#      70
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     140         if typ is None:
#     141             try:
# --> 142                 next(self.gen)
#     143             except StopIteration:
#     144                 return False
#
# /usr/local/lib/python3.10/dist-packages/uvicorn/server.py in capture_signals(self)
#     326         # done LIFO, see https://stackoverflow.com/questions/48434964
#     327         for captured_signal in reversed(self._captured_signals):
# --> 328             signal.raise_signal(captured_signal)
#     329
#     330     def handle_exit(self, sig: int, frame: FrameType | None) -> None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Rouge 평가

# %%
# 아래import 안되면 확인해주세요!
# !pip install nltk==3.5

from nltk.util import ngrams

def rouge(reference, hypothesis, n):
    reference_ngrams = list(ngrams(reference, n))
    hypothesis_ngrams = list(ngrams(hypothesis, n))

    # 겹치는 n-gram 개수 계산
    intersection = len(set(reference_ngrams) & set(hypothesis_ngrams))

    # reference 문장에 있는 n-gram 개수 계산
    reference_count = len(reference_ngrams)

    # hypothesis 문장에 있는 n-gram 개수 계산
    hypothesis_count = len(hypothesis_ngrams)

    # ROUGE-N 점수 계산
    rouge_score = intersection / max(reference_count, hypothesis_count)

    return rouge_score

# %%
# 예시 문장: 이렇게 예시문장들을 학습시켜줘야합니다.

# 채점 기준 문장 ( 손수 요약, 기계요약, 공지 전문 등)
reference_sentence = "The quick brown fox jumps over the lazy dog"
# 평가 대상 문장 (우리 모델의 결과)
hypothesis_sentence = "The fast brown fox jumps over the lazy dog"

# ROUGE-1 점수 계산
rouge_1_score = rouge(reference_sentence.split(), hypothesis_sentence.split(), 1)
print("ROUGE-1 Score:", rouge_1_score)

# ROUGE-2 점수 계산
rouge_2_score = rouge(reference_sentence.split(), hypothesis_sentence.split(), 2)
print("ROUGE-2 Score:", rouge_2_score)
# Out:
# ROUGE-1 Score: 0.8888888888888888
# ROUGE-2 Score: 0.75

# %% [markdown]
# ### 사용할 데이터 세트 로딩

# %%
import os
#마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

gongji = pd.read_csv('./drive/MyDrive/csv모음/final_merged_gongji(0501).csv')
haksa = pd.read_csv('./drive/MyDrive/csv모음/merged_haksa.csv')
hiring = pd.read_csv('./drive/MyDrive/csv모음/merged_hire.csv')
janghak = pd.read_csv('./drive/MyDrive/csv모음/merged_janghak.csv')


#파일복사
# 원본 데이터 보존 위해 copy 데이터 생성
gongji_copy = gongji.copy()
haksa_copy = haksa.copy()
hiring_copy = hiring.copy()
janghak_copy = janghak.copy()

# %% [markdown]
# ### rouge 탐색 대상 선정
#
# - 막상해보니 ngram 교차도가 너무 낮아서 rouge-L이 적정할지도 모르겠음

# %% [markdown]
# 1. 공지
# - 27. 행정고시 사민재
# - 68. 신입생영어진단평가 추가시험
# 2. 학사
#
# 3. 장학
#
# 4. 채용

# %%
gongji_copy.loc[81,'content']
# Out:
# '\n세미오시스 연구센터, <2024 제1회 문화 세미오시스 비평교실> 온라인 개최 안내\n\n\n한국외대 세미오시스 연구센터(센터장 서종석)에서 2월 14일 (수)에 2024년 첫 번째 <문화 세미오시스 비평교실>을 개최합니다.\n\n올해 문화 세미오시스 비평교실의 테마는 질베르 시몽동, 폴 리쾨르, 르네 지라르의 사상과 21세기의 대화입니다.\n\n특히, 올해 비평교실은 각 사상가에 대한 이론과 실제를 융합하여 우리 시대에 필요한 이야기를 들려줄 전문가를 모시고, 마스터클래스로 운영합니다. 마스터클래스는 각 2회로 구성되며, 1회에서는 사상가의 이론을 소개하고, 2회에서는 21세기 문화와 연결지어 이론 및 개념의 적용과 실천을 논의합니다.\n\n첫 번째 비평교실은 김재희 교수님을 모시고 ‘질베르 시몽동의 기술 철학을 중심으로: 21세기 기술 문화 현상에 대하여’라는 주제로 진행됩니다.\n\n관심 있는 분들의 많은 참여 부탁드립니다\n\n\n■ 강연자: 김재희 (을지대 교양학부 교수)\n\n■ 토론자: 이지영 (한국외대 세미오시스 연구센터 HK연구교수)\n\n■ 사회자: 강병창 (한국외대 세미오시스 연구센터 HK교수)\n\n■ 참여 방법: 온라인 웹엑스 접속 (링크: https://hufs.webex.com/meet/semiosis / 포스터 내 QR 접속)\n\n■ 일시: 2024. 2. 14 (수), 오후 2시 - 4시\n\n\n\n\n\n\n2024.1.31.\n\n세미오시스 연구센터\n\n\n2024 문화 세미오시스 비평교실 Master Class\n질베르 시몽동의 기술 철학을 중심으로 21세기 기술 문화 현상에 대하여\n\n강연\n김재희\n을지대 교양학부 교수\n서울대 철학과 서양철학 박사\n\n저서\n「시몽동의 기술철학: 포스트휴먼 사회를 위한 청사진」\n「베르그손의 잠재적 무의식」\n「물질과 기억: 반복과 차이의 운동」 등\n\n역서\n「기술적 대상들의 존재양식에 대하여」\n「도덕과 종교의 두 원천」\n「은유로서의 건축」 등\n\n강연일자\n회차: 1회\n일시: 2월 14일(수) 오후 2시~4시\n소주제: 정보와 변환의 존재론: 시몽동의 개체화론\n\n회차: 2회\n일시: 4월 19일(금) 오후 2시~4시\n소주제: 기술적 대상의 존재양식: 시몽동의 기술철학과 현대적 함의\n\n토론\n이지영\n한국외대 세미오시스 연구센터 HK연구교수\n\n사회\n강병창 \n한국외대 세미오시스 연구센터 HK 교수\n\n참여방법\n온라인 Webex 접속 https://hufs.webex.com/meet/semiosis\n\n'

# %%
stopwords_path = '/content/stopwords_list.txt'
summarizer = Summarizer(stopwords_path)
content_to_summarize = gongji_copy.loc[68, 'content']
title = gongji_copy.loc[68, 'title']
summary = summarizer.summarize_content(title, content_to_summarize)

sent = ''
print(title)
print('')
for i in summary:
  print(i)
  sent += i
#rouge를 위해 추가
#print(sent)
# Out:
# [글로벌](온라인) 신입생영어진단평가 추가 시험 안내
#
# (온라인) 추가시험은 4회차중 반드시 한번만 응시해야 하고,   가급적 안정적인 1회차~3회차에 응시하시기 바랍니다
# [글로벌](온라인) 신입생영어진단평가 추가 시험 안내
# 로그인(ID:학번, PW:주민번호 앞자리)후 온라인으로 시험 응시(시험 시간: 90분)

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.4)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24933 sha256=7b990c5e3ef7e13eb4ffd2be31bddf230c2df43a3661f3d53d04b2c92d15c4b6
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
# 예시 코드
from rouge_score import rouge_scorer

# 생성된 요약과 참조 요약
generated_summary = "온라인 신입생 영어 진단평가 추가 시험은 3월 4일에 4회차 중 한 번만 응시해야 하며, 대상자는 신입생 중 1차 시험 미응시자, 1차 시험 결과 '등급외' 대상자, 재학생 중 IFLEP 등급 미 부여자입니다. 시험 시간은 90분이며, 각 회차별로 안내된 접속 시간 내에 접속하여야 합니다. 시험 관련 문제 발생 시 HELP DESK(☎1644-5223)로 연락하고, 결과는 3월 5일 13시부터 확인할 수 있습니다."
reference_summary = sent

# ROUGE 평가
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference_summary, generated_summary)

# 결과 출력
for score in scores:
  print(score,':', scores.get(score))
# Out:
# rouge1 : Score(precision=0.2857142857142857, recall=0.6666666666666666, fmeasure=0.4)
# rouge2 : Score(precision=0.07692307692307693, recall=0.2, fmeasure=0.1111111111111111)
# rougeL : Score(precision=0.21428571428571427, recall=0.5, fmeasure=0.3)

# %% [markdown]
# ### rouge-u, rouge-su해보기
#
# https://velog.io/@crosstar1228/NLPRouge-score-Summarization%EC%9D%98-%ED%8F%89%EA%B0%80-Metric
#
# - 수연님 추천에 따라 RDASS, rouge-u, rouge su해보기
# - RDASS는 구현이 쉽지 않아보임...!

# %% [markdown]
# #### pyrouge 설치 및 관련 사항 설정

# %%
# !pip install pyrouge
# !pip install -U setuptools
# Out:
# Collecting pyrouge
#   Downloading pyrouge-0.1.3.tar.gz (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 806.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyrouge
#   Building wheel for pyrouge (setup.py) ... done
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-py3-none-any.whl size=191604 sha256=c46a533adcc4b89e42d6598759f23383618a4de2a76f7b529166b89a35e333ab
#   Stored in directory: /root/.cache/pip/wheels/9a/67/12/c5dd8ef8b4152bb8789eafd2a74a734e2dc7bb9eae02b768e7
# Successfully built pyrouge
# Installing collected packages: pyrouge
# Successfully installed pyrouge-0.1.3
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (67.7.2)
# Collecting setuptools
#   Using cached setuptools-70.0.0-py3-none-any.whl (863 kB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed setuptools-70.0.0

# %%
# !git clone https://github.com/andersjo/pyrouge.git rouge
# !cd rouge && python3 setup.py install
# Out:
# Cloning into 'rouge'...
# remote: Enumerating objects: 393, done.
# remote: Total 393 (delta 0), reused 0 (delta 0), pack-reused 393
# Receiving objects: 100% (393/393), 298.74 KiB | 3.02 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating pyrouge.egg-info
# writing pyrouge.egg-info/PKG-INFO
# writing dependency_links to pyrouge.egg-info/dependency_links.txt
# writing requirements to pyrouge.egg-info/requires.txt
# writing top-level names to pyrouge.egg-info/top_level.txt
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# reading manifest file 'pyrouge.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'pyrouge.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/pyrouge
# copying pyrouge/rouge.py -> build/lib/pyrouge
# copying pyrouge/__init__.py -> build/lib/pyrouge
# copying pyrouge/base.py -> build/lib/pyrouge
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/pyrouge
# copying build/lib/pyrouge/rouge.py -> build/bdist.linux-x86_64/egg/pyrouge
# copying build/lib/pyrouge/__init__.py -> build/bdist.linux-x86_64/egg/pyrouge
# copying build/lib/pyrouge/base.py -> build/bdist.linux-x86_64/egg/pyrouge
# byte-compiling build/bdist.linux-x86_64/egg/pyrouge/rouge.py to rouge.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrouge/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/pyrouge/base.py to base.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrouge.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrouge.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrouge.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrouge.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrouge.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying pyrouge.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating dist
# creating 'dist/pyrouge-0.1-py3.10.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pyrouge-0.1-py3.10.egg
# creating /usr/local/lib/python3.10/dist-packages/pyrouge-0.1-py3.10.egg
# Extracting pyrouge-0.1-py3.10.egg to /usr/local/lib/python3.10/dist-packages
# Adding pyrouge 0.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.10/dist-packages/pyrouge-0.1-py3.10.egg
# Processing dependencies for pyrouge==0.1
# Searching for pandas==2.0.3
# Best match: pandas 2.0.3
# Adding pandas 2.0.3 to easy-install.pth file
# detected new path './pyrouge-0.1-py3.10.egg'
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for beautifulsoup4==4.12.3
# Best match: beautifulsoup4 4.12.3
# Adding beautifulsoup4 4.12.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for numpy==1.25.2
# Best match: numpy 1.25.2
# Adding numpy 1.25.2 to easy-install.pth file
# Installing f2py script to /usr/local/bin
# Installing f2py3 script to /usr/local/bin
# Installing f2py3.10 script to /usr/local/bin
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for tzdata==2024.1
# Best match: tzdata 2024.1
# Adding tzdata 2024.1 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for pytz==2023.4
# Best match: pytz 2023.4
# Adding pytz 2023.4 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for soupsieve==2.5
# Best match: soupsieve 2.5
# Adding soupsieve 2.5 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.10/dist-packages
# Finished processing dependencies for pyrouge==0.1

# %%
# !wget https://github.com/kavgan/ROUGE-2.0/archive/refs/heads/master.zip -O rouge.zip
# !unzip rouge.zip
# !mv ROUGE-2.0-master /content/rouge/RELEASE-1.5.5
# Out:
# --2024-06-11 17:09:42--  https://github.com/kavgan/ROUGE-2.0/archive/refs/heads/master.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/kavgan/ROUGE-2.0/zip/refs/heads/master [following]
# --2024-06-11 17:09:43--  https://codeload.github.com/kavgan/ROUGE-2.0/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘rouge.zip’
#
# rouge.zip               [         <=>        ] 226.81M  10.4MB/s    in 22s
#
# 2024-06-11 17:10:05 (10.4 MB/s) - ‘rouge.zip’ saved [237829010]
#
# Archive:  rouge.zip
# 21c70e49f4c7ee2a36fbfd8b50232db1c4aa9d7c
#    creating: ROUGE-2.0-master/
#   inflating: ROUGE-2.0-master/.classpath
#  extracting: ROUGE-2.0-master/.gitignore
#   inflating: ROUGE-2.0-master/.project
#    creating: ROUGE-2.0-master/.settings/
#   inflating: ROUGE-2.0-master/.settings/org.eclipse.jdt.core.prefs
#   inflating: ROUGE-2.0-master/.settings/org.eclipse.m2e.core.prefs
#   inflating: ROUGE-2.0-master/LICENSE
#   inflating: ROUGE-2.0-master/README.md
#   inflating: ROUGE-2.0-master/_config.yml
#    creating: ROUGE-2.0-master/distribute/
#    creating: ROUGE-2.0-master/distribute/downloads/
#  extracting: ROUGE-2.0-master/distribute/downloads/rouge2-1.0-distribute.zip
#   inflating: ROUGE-2.0-master/distribute/log4j.properties
#    creating: ROUGE-2.0-master/distribute/resources/
#   inflating: ROUGE-2.0-master/distribute/resources/stopwords-rouge-default.txt
#   inflating: ROUGE-2.0-master/distribute/resources/stopwords-terrier-en.txt
#    creating: ROUGE-2.0-master/distribute/resources/taggers/
#   inflating: ROUGE-2.0-master/distribute/resources/taggers/english-bidirectional-distsim.tagger
#   inflating: ROUGE-2.0-master/distribute/resources/taggers/english-bidirectional-distsim.tagger.props
#   inflating: ROUGE-2.0-master/distribute/resources/taggers/english-caseless-left3words-distsim.tagger
#   inflating: ROUGE-2.0-master/distribute/resources/taggers/english-caseless-left3words-distsim.tagger.props
#   inflating: ROUGE-2.0-master/distribute/resources/taggers/english-left3words-distsim.tagger
#   inflating: ROUGE-2.0-master/distribute/resources/taggers/english-left3words-distsim.tagger.props
#   inflating: ROUGE-2.0-master/distribute/results.csv
#   inflating: ROUGE-2.0-master/distribute/rouge.properties
#   inflating: ROUGE-2.0-master/distribute/rouge2.0_0.2.jar
#    creating: ROUGE-2.0-master/distribute/test-summarization/
#    creating: ROUGE-2.0-master/distribute/test-summarization/reference/
#   inflating: ROUGE-2.0-master/distribute/test-summarization/reference/task1_englishReference1.txt
#   inflating: ROUGE-2.0-master/distribute/test-summarization/reference/task1_englishReference2.txt
#   inflating: ROUGE-2.0-master/distribute/test-summarization/reference/task2_persianReference1.txt
#    creating: ROUGE-2.0-master/distribute/test-summarization/system/
#   inflating: ROUGE-2.0-master/distribute/test-summarization/system/task1_englishSyssum1.txt
#   inflating: ROUGE-2.0-master/distribute/test-summarization/system/task1_englishSyssum2.txt
#   inflating: ROUGE-2.0-master/distribute/test-summarization/system/task2_persianSyssum1.txt
#    creating: ROUGE-2.0-master/docs/
#   inflating: ROUGE-2.0-master/docs/_config.yml
#   inflating: ROUGE-2.0-master/docs/usage-documentation.md
#    creating: ROUGE-2.0-master/lib/
#   inflating: ROUGE-2.0-master/lib/jaws-bin.jar
#   inflating: ROUGE-2.0-master/lib/snowball-stemmer-1.3.0.581.1.jar
#   inflating: ROUGE-2.0-master/lib/stanford-postagger-3.3.1.jar
#   inflating: ROUGE-2.0-master/pom.xml
#    creating: ROUGE-2.0-master/projects/
#    creating: ROUGE-2.0-master/projects/test-summarization/
#    creating: ROUGE-2.0-master/projects/test-summarization/reference/
#   inflating: ROUGE-2.0-master/projects/test-summarization/reference/task1_reference1.txt
#   inflating: ROUGE-2.0-master/projects/test-summarization/reference/task1_reference2.txt
#   inflating: ROUGE-2.0-master/projects/test-summarization/reference/task2_reference1.txt
#    creating: ROUGE-2.0-master/projects/test-summarization/system/
#   inflating: ROUGE-2.0-master/projects/test-summarization/system/task1_syssum1.txt
#   inflating: ROUGE-2.0-master/projects/test-summarization/system/task1_syssum2.txt
#   inflating: ROUGE-2.0-master/projects/test-summarization/system/task2_syssum1.txt
#    creating: ROUGE-2.0-master/resources/
#   inflating: ROUGE-2.0-master/resources/stopwords-rouge-default.txt
#   inflating: ROUGE-2.0-master/resources/stopwords-terrier-en.txt
#    creating: ROUGE-2.0-master/resources/taggers/
#   inflating: ROUGE-2.0-master/resources/taggers/README-Models.txt
#   inflating: ROUGE-2.0-master/resources/taggers/arabic-train.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/arabic-train.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/arabic.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/arabic.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/chinese-distsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/chinese-distsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/chinese-nodistsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/chinese-nodistsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/english-bidirectional-distsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/english-bidirectional-distsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/english-caseless-left3words-distsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/english-caseless-left3words-distsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/english-left3words-distsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/english-left3words-distsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/french.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/french.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/german-dewac.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/german-dewac.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/german-fast.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/german-fast.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/german-hgc.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/german-hgc.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/left3words-wsj-0-18.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/left3words-wsj-0-18.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-bidirectional-nodistsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-bidirectional-nodistsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-caseless-left3words-distsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-caseless-left3words-distsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-left3words-distsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-left3words-distsim.tagger.props
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-left3words-nodistsim.tagger
#   inflating: ROUGE-2.0-master/resources/taggers/wsj-0-18-left3words-nodistsim.tagger.props
#   inflating: ROUGE-2.0-master/results.csv
#   inflating: ROUGE-2.0-master/rouge.properties
#    creating: ROUGE-2.0-master/src/
#    creating: ROUGE-2.0-master/src/com/
#    creating: ROUGE-2.0-master/src/com/rxnlp/
#    creating: ROUGE-2.0-master/src/com/rxnlp/tools/
#    creating: ROUGE-2.0-master/src/com/rxnlp/tools/rouge/
#   inflating: ROUGE-2.0-master/src/com/rxnlp/tools/rouge/ROUGECalculator.java
#   inflating: ROUGE-2.0-master/src/com/rxnlp/tools/rouge/ROUGESettings.java
#   inflating: ROUGE-2.0-master/src/com/rxnlp/tools/rouge/SettingsUtil.java
#    creating: ROUGE-2.0-master/src/com/rxnlp/utils/
#    creating: ROUGE-2.0-master/src/com/rxnlp/utils/lang/
#   inflating: ROUGE-2.0-master/src/com/rxnlp/utils/lang/StopWordsHandler.java
#   inflating: ROUGE-2.0-master/src/com/rxnlp/utils/lang/WordNetDict.java
#   inflating: ROUGE-2.0-master/src/log4j.properties
#    creating: ROUGE-2.0-master/versions/
#    creating: ROUGE-2.0-master/versions/v1.0/
#  extracting: ROUGE-2.0-master/versions/v1.0/rouge2-1.0-runnable.zip
#    creating: ROUGE-2.0-master/versions/v1.2.1/
#  extracting: ROUGE-2.0-master/versions/v1.2.1/rouge2-1.2.1-runnable.zip
#    creating: ROUGE-2.0-master/versions/v1.2.2/
#   inflating: ROUGE-2.0-master/versions/v1.2.2/rouge2_v1.2.2_runnable.zip
#    creating: ROUGE-2.0-master/versions/v1.2/
#  extracting: ROUGE-2.0-master/versions/v1.2/rouge2-1.2-runnable.zip

# %%
# !mkdir -p /content/rouge/RELEASE-1.5.5/data

# %%
# !mkdir -p /root/.pyrouge
# !echo "[pyrouge]" > /root/.pyrouge/settings.ini
# !echo "home_dir = /content/rouge/RELEASE-1.5.5" >> /root/.pyrouge/settings.ini

# %%
import os
os.environ['ROUGE_HOME'] = '/content/rouge/tools/ROUGE-1.5.5'

# %%
# !pyrouge_set_rouge_path /content/rouge/tools/ROUGE-1.5.5
# Out:
# 2024-06-11 17:10:10,701 [MainThread  ] [INFO ]  Set ROUGE home directory to /content/rouge/tools/ROUGE-1.5.5.

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# #### rouge-u 실행

# %%
import os
os.makedirs("/tmp/tmpz47b_qdy/system")
os.makedirs("/tmp/tmpz47b_qdy/model")

# %%
import os
from pyrouge import Rouge155

# Sample reference and generated summaries
reference_text = "This is a reference summary."
generated_summary = "This is a generated summary."

# Write the summaries to files
with open("reference.txt", "w") as ref:
    ref.write(reference_text)

with open("generated.txt", "w") as gen:
    gen.write(generated_summary)

# Initialize the Rouge155 object
rouge = Rouge155()

# Set directories for ROUGE evaluation
#system_dir = "/tmp/tmpz47b_qdy/system"  # Change this to the directory containing system summaries
#model_dir = "/tmp/tmpz47b_qdy/model"    # Change this to the directory containing model summaries

system_dir = "/content"
model_dir = "/content"

# Add files to the ROUGE evaluation
rouge.system_dir = system_dir
rouge.model_dir = model_dir
rouge.system_filename_pattern = "generated.txt"
rouge.model_filename_pattern = "reference.txt"

# Evaluate the generated summary
scores = rouge.convert_and_evaluate()

print(scores)
# Out:
# 2024-06-11 17:16:45,236 [MainThread  ] [INFO ]  Writing summaries.
# INFO:global:Writing summaries.
# 2024-06-11 17:16:45,242 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpj76dje7r/system and model files to /tmp/tmpj76dje7r/model.
# INFO:global:Processing summaries. Saving system files to /tmp/tmpj76dje7r/system and model files to /tmp/tmpj76dje7r/model.
# 2024-06-11 17:16:45,247 [MainThread  ] [INFO ]  Processing files in /content.
# INFO:global:Processing files in /content.
# 2024-06-11 17:16:45,250 [MainThread  ] [INFO ]  Processing .config.
# INFO:global:Processing .config.
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-12-71082a02a253> in <cell line: 32>()
#      30
#      31 # Evaluate the generated summary
# ---> 32 scores = rouge.convert_and_evaluate()
#      33
#      34 print(scores)
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in convert_and_evaluate(self, system_id, split_sentences, rouge_args)
#     358         if split_sentences:
#     359             self.split_sentences()
# --> 360         self.__write_summaries()
#     361         rouge_output = self.evaluate(system_id, rouge_args)
#     362         return rouge_output
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __write_summaries(self)
#     487     def __write_summaries(self):
#     488         self.log.info("Writing summaries.")
# --> 489         self.__process_summaries(self.convert_summaries_to_rouge_format)
#     490
#     491     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __process_summaries(self, process_func)
#     480             "Processing summaries. Saving system files to {} and "
#     481             "model files to {}.".format(new_system_dir, new_model_dir))
# --> 482         process_func(self._system_dir, new_system_dir)
#     483         process_func(self._model_dir, new_model_dir)
#     484         self._system_dir = new_system_dir
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in convert_summaries_to_rouge_format(input_dir, output_dir)
#     199
#     200         """
# --> 201         DirectoryProcessor.process(
#     202             input_dir, output_dir, Rouge155.convert_text_to_rouge_format)
#     203
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/utils/file_utils.py in process(input_dir, output_dir, function)
#      26             logger.info("Processing {}.".format(input_file_name))
#      27             input_file = os.path.join(input_dir, input_file_name)
# ---> 28             with codecs.open(input_file, "r", encoding="UTF-8") as f:
#      29                 input_string = f.read()
#      30             output_string = function(input_string)
#
# /usr/lib/python3.10/codecs.py in open(filename, mode, encoding, errors, buffering)
#     904         # Force opening of the file in binary mode
#     905         mode = mode + 'b'
# --> 906     file = builtins.open(filename, mode, buffering)
#     907     if encoding is None:
#     908         return file
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/.config'

# %%
import os
from pyrouge import Rouge155

# Sample reference and generated summaries
reference_text = "This is a reference summary."
generated_summary = "This is a generated summary."

# Write the summaries to files
with open("/content/reference.txt", "w") as ref:
    ref.write(reference_text)

with open("/content/generated.txt", "w") as gen:
    gen.write(generated_summary)

# Initialize the Rouge155 object
rouge = Rouge155()

# Set directories for ROUGE evaluation
system_dir = "/content"  # Change this to the directory containing system summaries
model_dir = "/content"   # Change this to the directory containing model summaries

# Add files to the ROUGE evaluation
system_files = [f for f in os.listdir(system_dir) if os.path.isfile(os.path.join(system_dir, f))]
rouge.system_dir = system_dir
rouge.model_dir = model_dir

# Identify system and model files
system_file = None
model_file = None
for filename in system_files:
    if filename == "generated.txt":
        system_file = filename
    elif filename == "reference.txt":
        model_file = filename

# If system and model files are identified, set them for ROUGE evaluation
if system_file and model_file:
    rouge.system_filename_pattern = system_file
    rouge.model_filename_pattern = model_file
    # Evaluate the generated summary
    scores = rouge.convert_and_evaluate()
    print(scores)
else:
    print("System or model files not found.")
# Out:
# 2024-06-11 17:23:03,273 [MainThread  ] [INFO ]  Writing summaries.
# INFO:global:Writing summaries.
# 2024-06-11 17:23:03,289 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmp2ca2b6te/system and model files to /tmp/tmp2ca2b6te/model.
# INFO:global:Processing summaries. Saving system files to /tmp/tmp2ca2b6te/system and model files to /tmp/tmp2ca2b6te/model.
# 2024-06-11 17:23:03,305 [MainThread  ] [INFO ]  Processing files in /content.
# INFO:global:Processing files in /content.
# 2024-06-11 17:23:03,311 [MainThread  ] [INFO ]  Processing .config.
# INFO:global:Processing .config.
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-21-ae8ac261b4ac> in <cell line: 37>()
#      39     rouge.model_filename_pattern = model_file
#      40     # Evaluate the generated summary
# ---> 41     scores = rouge.convert_and_evaluate()
#      42     print(scores)
#      43 else:
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in convert_and_evaluate(self, system_id, split_sentences, rouge_args)
#     358         if split_sentences:
#     359             self.split_sentences()
# --> 360         self.__write_summaries()
#     361         rouge_output = self.evaluate(system_id, rouge_args)
#     362         return rouge_output
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __write_summaries(self)
#     487     def __write_summaries(self):
#     488         self.log.info("Writing summaries.")
# --> 489         self.__process_summaries(self.convert_summaries_to_rouge_format)
#     490
#     491     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __process_summaries(self, process_func)
#     480             "Processing summaries. Saving system files to {} and "
#     481             "model files to {}.".format(new_system_dir, new_model_dir))
# --> 482         process_func(self._system_dir, new_system_dir)
#     483         process_func(self._model_dir, new_model_dir)
#     484         self._system_dir = new_system_dir
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in convert_summaries_to_rouge_format(input_dir, output_dir)
#     199
#     200         """
# --> 201         DirectoryProcessor.process(
#     202             input_dir, output_dir, Rouge155.convert_text_to_rouge_format)
#     203
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/utils/file_utils.py in process(input_dir, output_dir, function)
#      26             logger.info("Processing {}.".format(input_file_name))
#      27             input_file = os.path.join(input_dir, input_file_name)
# ---> 28             with codecs.open(input_file, "r", encoding="UTF-8") as f:
#      29                 input_string = f.read()
#      30             output_string = function(input_string)
#
# /usr/lib/python3.10/codecs.py in open(filename, mode, encoding, errors, buffering)
#     904         # Force opening of the file in binary mode
#     905         mode = mode + 'b'
# --> 906     file = builtins.open(filename, mode, buffering)
#     907     if encoding is None:
#     908         return file
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/.config'

# %%
os.path.exists('/content/.config')
# Out:
# True

# %%
import os

# 현재 디렉토리 확인
current_directory = os.getcwd()

# 생성된 파일의 전체 경로
generated_txt_path = os.path.join(current_directory, "generated.txt")

print("생성된 generated.txt 파일의 경로:", generated_txt_path)
# Out:
# 생성된 generated.txt 파일의 경로: /content/generated.txt

# %%
pwd
# Out:
# '/content'

# %%
stopwords_path = '/content/stopwords_list.txt'
summarizer = Summarizer(stopwords_path)
content_to_summarize = gongji_copy.loc[68, 'content']
title = gongji_copy.loc[68, 'title']
summary = summarizer.summarize_content(title, content_to_summarize)

sent = ''
print(title)
print('')
for i in summary:
  print(i)
  sent += i
#rouge를 위해 추가
print(sent)
# Out:
# [글로벌](온라인) 신입생영어진단평가 추가 시험 안내
#
# (온라인) 추가시험은 4회차중 반드시 한번만 응시해야 하고,   가급적 안정적인 1회차~3회차에 응시하시기 바랍니다
# [글로벌](온라인) 신입생영어진단평가 추가 시험 안내
# 로그인(ID:학번, PW:주민번호 앞자리)후 온라인으로 시험 응시(시험 시간: 90분)
# (온라인) 추가시험은 4회차중 반드시 한번만 응시해야 하고,   가급적 안정적인 1회차~3회차에 응시하시기 바랍니다[글로벌](온라인) 신입생영어진단평가 추가 시험 안내로그인(ID:학번, PW:주민번호 앞자리)후 온라인으로 시험 응시(시험 시간: 90분)

# %%
gongji_copy.loc[68,'content']
# Out:
# '\n[글로벌](온라인) 신입생영어진단평가 추가 시험 안내\n\n\n# 주의 사항:\n(온라인) 추가시험은 4회차중 반드시 한번만 응시해야 하고,   가급적 안정적인 1회차~3회차에 응시하시기 바랍니다.(College English 해당 학부) 대면 추가시험(28일 오전)은 외국어교육센터 570번 공지를 참조 바랍니다\n\n.........................................................................................................................\n※추가 (온라인) 시험 일정 안내 -3월 4일(월)\n\n웹사이트(주소:http://exam.cufs.ac.kr/main/index.asp)에 접속하여\n\n로그인(ID:학번, PW:주민번호 앞자리)후 온라인으로 시험 응시(시험 시간: 90분)\n\n1.대상자: 아래 대상자는 별도의 신청 없이 4회차 중 가능한 시간에 응시할 수 있습니다\n- (신입생) 1차 시험 미응시자\n- (신입생) 1차 시험 결과 ＇등급외＇(320점/1,000점) 대상자\n- (재학생) IFLEP등급 미 부여자로 외국어교육센터 신청자\n\n2.일정: 응시시간이 90분입니다. 반드시 안내된 접속시간 안에 접속하여 응시하시기 바랍니다.\n\n\n\n\n(1회차) 10:00 ~ 12:00 (10시 30분까지 접속)\n\n\n\n(2회차) 13:00 ~ 15:00(13시 30분까지 접속)\n\n\n\n(3회차) 15:30 ~ 17:30(16시 00분까지 접속)\n\n\n\n(4회차) 18:00 ~ 20:00(18시 30분까지 접속)\n\n\n\n(사전 테스트는 3월 3일 09:00-22:00)\n\n※온라인 시험 진행과 관련해 문제가 발생할 경우HELP DESK에 즉시 연락해 조치 받음\n(★HELP DESK연락처:☎1644-5223,아이디, 비밀번호 등)\n(기타 시험관련문의: 02-2173-8768, 02-2173-2375)\n\n3. 추가 시험 대상자의 등급은 3월 5일 13시부터 확인 가능할 예정이며, 등급이 부여된 후 수강신청 변경기간에 등급에 맞는 반으로 수강신청하면 됩니다.\n기타 안내는 외국어교육센터(글로벌)의 공지를 꼭 참조 바랍니다.\n\n\n'

# %%
pip install pyrouge
# Out:
# Requirement already satisfied: pyrouge in /usr/local/lib/python3.10/dist-packages (0.1.3)

# %%
from pyrouge import Rouge155

# %%
def evaluate_summary_with_pyrouge(reference: str, summary: str):
    rouge = Rouge155()

    # 임시 파일로 참조 요약문과 생성된 요약문 저장
    with open('reference.txt', 'w', encoding='utf-8') as f:
        f.write(reference)
    with open('summary.txt', 'w', encoding='utf-8') as f:
        f.write(summary)

    # ROUGE 평가 수행
    rouge.system_dir = '.'
    rouge.model_dir = '.'
    rouge.system_filename_pattern = 'summary.txt'
    rouge.model_filename_pattern = 'reference.txt'

    rouge_output = rouge.convert_and_evaluate()
    scores = rouge.output_to_dict(rouge_output)
    return scores

# %%
import os

os.chdir("/usr/local/lib/python3.10/dist-packages")
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages'

# %%
# 예제 사용
reference_text = "시험 일정 안내 -3월 4일(월)    주의 사항:\n(온라인) 추가시험은 4회차중 반드시 한번만 응시해야 하고,   가급적 안정적인 1회차~3회차에 응시하시기 바랍니다.    응시시간이 90분입니다."
generated_summary = sent

scores = evaluate_summary_with_pyrouge(reference_text, generated_summary)
print(scores)
# Out:
# 2024-06-11 17:35:37,426 [MainThread  ] [INFO ]  Writing summaries.
# INFO:global:Writing summaries.
# 2024-06-11 17:35:37,434 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpa5lc8j54/system and model files to /tmp/tmpa5lc8j54/model.
# INFO:global:Processing summaries. Saving system files to /tmp/tmpa5lc8j54/system and model files to /tmp/tmpa5lc8j54/model.
# 2024-06-11 17:35:37,442 [MainThread  ] [INFO ]  Processing files in ..
# INFO:global:Processing files in ..
# 2024-06-11 17:35:37,455 [MainThread  ] [INFO ]  Processing pkg_resources.
# INFO:global:Processing pkg_resources.
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-23-598c064066ff> in <cell line: 5>()
#       3 generated_summary = sent
#       4
# ----> 5 scores = evaluate_summary_with_pyrouge(reference_text, generated_summary)
#       6 print(scores)
#
# <ipython-input-21-9eb551db8c58> in evaluate_summary_with_pyrouge(reference, summary)
#      14     rouge.model_filename_pattern = 'reference.txt'
#      15
# ---> 16     rouge_output = rouge.convert_and_evaluate()
#      17     scores = rouge.output_to_dict(rouge_output)
#      18     return scores
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in convert_and_evaluate(self, system_id, split_sentences, rouge_args)
#     358         if split_sentences:
#     359             self.split_sentences()
# --> 360         self.__write_summaries()
#     361         rouge_output = self.evaluate(system_id, rouge_args)
#     362         return rouge_output
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __write_summaries(self)
#     487     def __write_summaries(self):
#     488         self.log.info("Writing summaries.")
# --> 489         self.__process_summaries(self.convert_summaries_to_rouge_format)
#     490
#     491     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __process_summaries(self, process_func)
#     480             "Processing summaries. Saving system files to {} and "
#     481             "model files to {}.".format(new_system_dir, new_model_dir))
# --> 482         process_func(self._system_dir, new_system_dir)
#     483         process_func(self._model_dir, new_model_dir)
#     484         self._system_dir = new_system_dir
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in convert_summaries_to_rouge_format(input_dir, output_dir)
#     199
#     200         """
# --> 201         DirectoryProcessor.process(
#     202             input_dir, output_dir, Rouge155.convert_text_to_rouge_format)
#     203
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/utils/file_utils.py in process(input_dir, output_dir, function)
#      26             logger.info("Processing {}.".format(input_file_name))
#      27             input_file = os.path.join(input_dir, input_file_name)
# ---> 28             with codecs.open(input_file, "r", encoding="UTF-8") as f:
#      29                 input_string = f.read()
#      30             output_string = function(input_string)
#
# /usr/lib/python3.10/codecs.py in open(filename, mode, encoding, errors, buffering)
#     904         # Force opening of the file in binary mode
#     905         mode = mode + 'b'
# --> 906     file = builtins.open(filename, mode, buffering)
#     907     if encoding is None:
#     908         return file
#
# IsADirectoryError: [Errno 21] Is a directory: './pkg_resources'

# %%
import os
os.path.exists('/usr/local/lib/python3.10/dist-packages (0.1.3)')
# Out:
# False

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# 다시

# %%
pip install pyrouge --target=usr/lib/python3.10/distutils
# Out:
# Collecting pyrouge
#   Using cached pyrouge-0.1.3-py3-none-any.whl
# Installing collected packages: pyrouge
# Successfully installed pyrouge-0.1.3
# WARNING: Target directory /content/usr/lib/python3.10/distutils/pyrouge-0.1.3.dist-info already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/usr/lib/python3.10/distutils/pyrouge already exists. Specify --upgrade to force replacement.
# WARNING: Target directory /content/usr/lib/python3.10/distutils/bin already exists. Specify --upgrade to force replacement.

# %%
# 예제 요약문
summary_text = "This is a sample summary for ROUGE evaluation."
# 예제 참조 요약문
reference_text = "This is a reference summary used for ROUGE evaluation."

# %%
from pyrouge import Rouge155

# Rouge155 객체 생성
rouge = Rouge155()

# 요약문과 참조 요약문을 파일로 저장
with open("summary.txt", "w") as f:
    f.write(summary_text)
with open("reference.txt", "w") as f:
    f.write(reference_text)

# 시스템 디렉토리와 모델 디렉토리 설정
rouge.system_dir = "."
rouge.model_dir = "."
rouge.system_filename_pattern = "summary.txt"
rouge.model_filename_pattern = "reference.txt"

# ROUGE 계산 실행
scores = rouge.convert_and_evaluate(rouge_args="-e /path/to/ROUGE-1.5.5")
print(scores)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1e826e5c147d> in <cell line: 4>()
#       2
#       3 # Rouge155 객체 생성
# ----> 4 rouge = Rouge155()
#       5
#       6 # 요약문과 참조 요약문을 파일로 저장
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __init__(self, rouge_dir, rouge_args)
#      86         self._config_file = None
#      87         self._settings_file = self.__get_config_path()
# ---> 88         self.__set_rouge_dir(rouge_dir)
#      89         self.args = self.__clean_rouge_args(rouge_args)
#      90         self._system_filename_pattern = None
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __set_rouge_dir(self, home_dir)
#     400         """
#     401         if not home_dir:
# --> 402             self._home_dir = self.__get_rouge_home_dir_from_settings()
#     403         else:
#     404             self._home_dir = home_dir
#
# /usr/local/lib/python3.10/dist-packages/pyrouge/Rouge155.py in __get_rouge_home_dir_from_settings(self)
#     414     def __get_rouge_home_dir_from_settings(self):
#     415         config = ConfigParser()
# --> 416         with open(self._settings_file) as f:
#     417             if hasattr(config, "read_file"):
#     418                 config.read_file(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/.pyrouge/settings.ini'

# %%
import os

# ROUGE-1.5.5 실행 파일 이름
filename = "ROUGE-1.5.5.pl"

# "/"부터 시작해서 루트 디렉토리 아래 모든 파일과 디렉토리를 찾음
for root, dirs, files in os.walk('/'):
    if filename in files:
        # 실행 파일을 찾으면 해당 파일의 경로를 출력
        print("ROUGE-1.5.5가 설치된 경로:", os.path.join(root, filename))
        break  # 실행 파일을 찾았으므로 더 이상 탐색할 필요가 없음

# %% [markdown]
# ## 0612 rouge

# %%
# korouge 다운받기
# !pip install korouge_score
from korouge_score import rouge_scorer
# Out:
# Requirement already satisfied: korouge_score in /usr/local/lib/python3.10/dist-packages (0.1.4)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from korouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from korouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from korouge_score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from korouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->korouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->korouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->korouge_score) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->korouge_score) (4.66.4)

# %%
scorer = rouge_scorer.RougeScorer(["rouge1", "rouge2", "rougeL", "rougeLsum"])

ref = "안녕하세요 반가워요 오늘 뭐 먹을래요?"
pred = "아 반가워 반가워 오늘 뭐 할래요 안녕하긴해??"

print(scorer.score(ref, pred))
# Out:
# {'rouge1': Score(precision=0.2857142857142857, recall=0.4, fmeasure=0.3333333333333333), 'rouge2': Score(precision=0.16666666666666666, recall=0.25, fmeasure=0.2), 'rougeL': Score(precision=0.2857142857142857, recall=0.4, fmeasure=0.3333333333333333), 'rougeLsum': Score(precision=0.2857142857142857, recall=0.4, fmeasure=0.3333333333333333)}

# %% [markdown]
# # 테스트시나리오

# %% [markdown]
# 1. <s>이미지만 있는 경우 -> 공백만 들어감.
#
# { "title": "Some title",
# "content": {
#      "image": "https://example.com/image.jpg"
# }}
# -> 오류남.
#
#
# -  이미지가 content, image로 따로들어오는 경우
#
#
# ```
# {
#   "title": "Sample Title",
#   "content": {
#     "image": {
#       "url": "https://example.com/image.jpg",
#       "alt": "An example image",
#       "caption": "This is an example caption."
#     }
#   }
# }
# ```
#
#
# -> 위에 문장이나 공백이 그대로 반환된다 (위의 json 처리를 할경우. 근데 지금 저 요청하면 internal servererror 나는 중)
#
# **422 Unprocessable Entity를 처리하는 방법을 문의할 필요가 있다.**
# - 우리가 422를 그냥 반환하면 프론트에서 응답처리를 별도로 해줄 수 있나??
# - 아니면 예외처리 혹시 제안해주실 수 있는 방법이있는지 ㅠㅠ </s>
#
# -> 이미지 자체가 파싱이 안됨. 타당성 검사는 인섭님 선에서 걸리기 때문에 422 에러 처리할 필요 X
#
# 2. 이미지+2줄 이내 텍스트인 경우 -> 위의 경우의수에 따라 달라짐. image에 따로 태그들이 생기면 작동됨
#
# 3. 3줄 이상인 텍스트가 있는 경우 -> 요약 잘됨
#
# 4. 두줄 이내 텍스트: 그대로 반환
#
# 5. 서버 에러시 해당 적용되니 "서버에러가 발생했습니다" 반환 잘됨
#
# 6. value error : 외국어 공지 넣어보기 -> 200ok로 처리돼서 반환이 빈리스트로 처리됨 (영어, 포어, 중국어 모두 마찬가지)
# - isforeign에 빈리스트를 걸어놔서 그랬던 것. 반환값 "자세한 내용 본문참고"로 바꿨더니 정상응답옴
#
# 7. 공지에 한국어, 외국어 비율 테스트

# %% [markdown]
# + api 결합이 잘됐는지

# %% [markdown]
# # 0613 Todo
# - rouge 테스트 결과
# - AWS EC2 배포 알아보기 (되면 좋음)
# - 발표용 비교군 마련
