# %%
#호출코드모음
import pandas as pd
import os
#마운트
from google.colab import drive
drive.mount('/content/drive')
import re
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
#단어 빈도셀 때
from collections import Counter
import string
# Out:
# Mounted at /content/drive

# %%
#os.chdir('..')
os.getcwd()
# Out:
# '/content'

# %%
gongji = pd.read_csv('./drive/MyDrive/csv모음/final_merged_gongji(0501).csv')
haksa = pd.read_csv('./drive/MyDrive/csv모음/merged_haksa.csv')
hiring = pd.read_csv('./drive/MyDrive/csv모음/merged_hire.csv')
janghak = pd.read_csv('./drive/MyDrive/csv모음/merged_janghak.csv')


#파일복사
# 원본 데이터 보존 위해 copy 데이터 생성
gongji_copy = gongji.copy()
haksa_copy = haksa.copy()
hiring_copy = hiring.copy()
janghak_copy = janghak.copy()

# %% [markdown]
# # github 클론해오기

# %%
# !git clone https://github.com/lovit/textrank.git
# Out:
# Cloning into 'textrank'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 232 (delta 1), reused 1 (delta 0), pack-reused 225
# Receiving objects: 100% (232/232), 1.21 MiB | 11.09 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
# %cd textrank
# Out:
# /content/textrank

# %%
# 이제 리포지토리의 코드를 사용할 수 있습니다.
from textrank import KeywordSummarizer, KeysentenceSummarizer

# 예시 코드
def example_tokenize(sentence):
    return sentence.split()

sentences = [
    "[공통]이중전공변경 배정 확정 공고",
    "2019학년도 제2학기 이중전공 변경 배정 결과를 아래와 같이 공고함.",
    "아 래",
    "1. 결과조회 : 종합정보시스템 → 전공/교직관리 → 이중전공 변경신청 → 안내사항",
    "2. 이중전공 변경 시에 배정된 학생은 추후 이중전공 변경 신청 불가",
    "미배정된 학생은 기존 이수중인 이중전공/부전공이 유지되며, 추후 이중전공 변경 기간 중 신청 가능",
    "3. 2020년 2월 졸업예정자(4학년 수료_졸업대기 포함)는 반드시 1월초까지 이수구분변경신청을 하여 영역별 졸업 학점에 누락 되는 일이 없도록 해야 함",
    "4. 이중전공 변경에 따라 성적 조회 후, 변경되지 않은 이수구분의 수정은 학사종합지원센터 내 1전공 소속 단과대학 창구에 방문하여 이수구분변경신청원을 작성하여 제출 하여야 함(방학 및 학기 중 가능)",
    "5. 기타사항",
    "(1) 부전공, 전공심화+부전공, 단일전공(기존 이중전공/부전공 취소) 신청기간",
    "2020.1.29~1.31 종합정보시스템에서 신청(1월 중순 학사공지 참조 바람)",
    "(2) 다음 학기 이중전공 변경기간은 5월초로 예정되어 있음.",
    "2020. 1",
    "교무처장"
]

# KeywordSummarizer 인스턴스 생성
summarizer = KeywordSummarizer(tokenize=example_tokenize, verbose=True)

# 키워드 요약 실행
keywords = summarizer.summarize(sentences)
print(keywords)
# Out:
# word cooccurrence counting from 14 sents was done
# trained TextRank. n words = 9
# [('이중전공', 2.177487658081866), ('변경', 1.6344055453608695), ('신청', 0.980356094315742), ('추후', 0.980356094315742), ('학생은', 0.980356094315742), ('→', 0.8587009437892201), ('중', 0.7072369173856135), ('학기', 0.3839479292676792), ('배정', 0.29715272316752217)]

# %% [markdown]
# ## konlpy komoran

# %%
#konlpy 설치확인
# !pip install konlpy
# !apt-get update
# !apt-get install -y openjdk-11-jdk

from konlpy.tag import Komoran

komoran = Komoran()

def komoran_tokenize(sent):
    words = komoran.pos(sent, join=True)
    # 품사 뽑아오기 (명사, 동사, 형용사, 어간)
    words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
    return words
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 60.4 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 41.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.0)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,118 kB]
# Fetched 2,351 kB in 2s (1,160 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libfontenc1
#   libice-dev libsm-dev libxkbfile1 libxt-dev libxtst6 libxxf86dga1 openjdk-11-jre x11-utils
# Suggested packages:
#   libice-doc libsm-doc libxt-doc openjdk-11-demo openjdk-11-source visualvm mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java libatk-wrapper-java-jni libfontenc1
#   libice-dev libsm-dev libxkbfile1 libxt-dev libxtst6 libxxf86dga1 openjdk-11-jdk openjdk-11-jre
#   x11-utils
# 0 upgraded, 14 newly installed, 0 to remove and 45 not upgraded.
# Need to get 5,521 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu3 [12.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-utils amd64 7.7+5build2 [206 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java all 0.38.0-5build1 [53.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-wrapper-java-jni amd64 0.38.0-5build1 [49.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice-dev amd64 2:1.0.10-1build2 [51.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm-dev amd64 2:1.2.3-1build2 [18.1 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt-dev amd64 1:1.2.1-1 [396 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jre amd64 11.0.22+7-0ubuntu2~22.04.1 [214 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jdk amd64 11.0.22+7-0ubuntu2~22.04.1 [1,339 kB]
# Fetched 5,521 kB in 0s (15.9 MB/s)
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../01-fonts-dejavu-extra_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-2build1) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../02-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../03-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../04-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../05-libxxf86dga1_2%3a1.1.5-0ubuntu3_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../06-x11-utils_7.7+5build2_amd64.deb ...
# Unpacking x11-utils (7.7+5build2) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../07-libatk-wrapper-java_0.38.0-5build1_all.deb ...
# Unpacking libatk-wrapper-java (0.38.0-5build1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../08-libatk-wrapper-java-jni_0.38.0-5build1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../09-libice-dev_2%3a1.0.10-1build2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-1build2) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../10-libsm-dev_2%3a1.2.3-1build2_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1build2) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../11-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package openjdk-11-jre:amd64.
# Preparing to unpack .../12-openjdk-11-jre_11.0.22+7-0ubuntu2~22.04.1_amd64.deb ...
# Unpacking openjdk-11-jre:amd64 (11.0.22+7-0ubuntu2~22.04.1) ...
# Selecting previously unselected package openjdk-11-jdk:amd64.
# Preparing to unpack .../13-openjdk-11-jdk_11.0.22+7-0ubuntu2~22.04.1_amd64.deb ...
# Unpacking openjdk-11-jdk:amd64 (11.0.22+7-0ubuntu2~22.04.1) ...
# Setting up libice-dev:amd64 (2:1.0.10-1build2) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1build2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu3) ...
# Setting up openjdk-11-jre:amd64 (11.0.22+7-0ubuntu2~22.04.1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up openjdk-11-jdk:amd64 (11.0.22+7-0ubuntu2~22.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-11-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libatk-wrapper-java (0.38.0-5build1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.38.0-5build1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
sents = [
    "[공통]이중전공변경 배정 확정 공고",
    "2019학년도 제2학기 이중전공 변경 배정 결과를 아래와 같이 공고함.",
    "아 래",
    "1. 결과조회 : 종합정보시스템 → 전공/교직관리 → 이중전공 변경신청 → 안내사항",
    "2. 이중전공 변경 시에 배정된 학생은 추후 이중전공 변경 신청 불가",
    "미배정된 학생은 기존 이수중인 이중전공/부전공이 유지되며, 추후 이중전공 변경 기간 중 신청 가능",
    "3. 2020년 2월 졸업예정자(4학년 수료_졸업대기 포함)는 반드시 1월초까지 이수구분변경신청을 하여 영역별 졸업 학점에 누락 되는 일이 없도록 해야 함",
    "4. 이중전공 변경에 따라 성적 조회 후, 변경되지 않은 이수구분의 수정은 학사종합지원센터 내 1전공 소속 단과대학 창구에 방문하여 이수구분변경신청원을 작성하여 제출 하여야 함(방학 및 학기 중 가능)",
    "5. 기타사항",
    "(1) 부전공, 전공심화+부전공, 단일전공(기존 이중전공/부전공 취소) 신청기간",
    "2020.1.29~1.31 종합정보시스템에서 신청(1월 중순 학사공지 참조 바람)",
    "(2) 다음 학기 이중전공 변경기간은 5월초로 예정되어 있음.",
    "2020. 1",
    "교무처장"
]

# %% [markdown]
# ## textrank 실습

# %%
from textrank import KeywordSummarizer

keyword_extractor = KeywordSummarizer(
    tokenize = komoran_tokenize,
    window = -1,
    verbose = False
)

keywords = keyword_extractor.summarize(sents, topk=30)

# %%
keywords
# Out:
# [('전공/NNG', 3.2751259332416938),
#  ('변경/NNG', 2.389028571895241),
#  ('이중/NNP', 2.2942720911081387),
#  ('하/VV', 1.5570021598763795),
#  ('이수/NNP', 1.4255880912340149),
#  ('신청/NNP', 1.2386338965384804),
#  ('구분/NNG', 1.103485312624934),
#  ('부전공/NNG', 0.9940387228909785),
#  ('종합/NNG', 0.9060342226109984),
#  ('배정/NNG', 0.8731002606322665),
#  ('가능/XR', 0.8312899705566449),
#  ('중/NNB', 0.8312899705566449),
#  ('조회/NNP', 0.765549818557773),
#  ('학기/NNG', 0.7446952364342982),
#  ('추후/NNG', 0.6631645126775891),
#  ('학생/NNG', 0.6631645126775891),
#  ('학사/NNP', 0.6492012237476299),
#  ('기존/NNG', 0.6393231893370246),
#  ('졸업/NNG', 0.5912062345339331),
#  ('기간/NNG', 0.5525929514466796),
#  ('결과/NNG', 0.5392619020882186),
#  ('정보/NNG', 0.5333219288331745),
#  ('시스템/NNG', 0.5333219288331745),
#  ('학년/NNG', 0.5086279338477264),
#  ('1월/NNP', 0.5024653811716224),
#  ('사항/NNG', 0.39521404204715194)]

# %%
from textrank import KeysentenceSummarizer

summarizer = KeysentenceSummarizer(tokenize = komoran_tokenize, min_sim = 0.5)
keysents = summarizer.summarize(sents, topk=10)

# %%
summarizer = KeysentenceSummarizer(tokenize = komoran_tokenize, min_sim = 0.3)
keysents = summarizer.summarize(sents, topk=3)

# %%
for i in range(3):
  print(keysents[i][2])
# Out:
# 미배정된 학생은 기존 이수중인 이중전공/부전공이 유지되며, 추후 이중전공 변경 기간 중 신청 가능
# 4. 이중전공 변경에 따라 성적 조회 후, 변경되지 않은 이수구분의 수정은 학사종합지원센터 내 1전공 소속 단과대학 창구에 방문하여 이수구분변경신청원을 작성하여 제출 하여야 함(방학 및 학기 중 가능)
# 1. 결과조회 : 종합정보시스템 → 전공/교직관리 → 이중전공 변경신청 → 안내사항

# %%
# 띄어쓰기로 나누는 토크나이저 확인
def subword_tokenizer(sent, n=3):
    def subword(token, n):
        if len(token) <= n:
            return [token]
        return [token[i:i+n] for i in range(len(token) - n)]
    return [sub for token in sent.split() for sub in subword(token, n)]

# %%
summarizer = KeysentenceSummarizer(tokenize = subword_tokenizer, min_sim = 0.3)
keysents = summarizer.summarize(sents, topk=3)

# %%
for i in range(3):
  print(keysents[i][2])
# Out:
# 미배정된 학생은 기존 이수중인 이중전공/부전공이 유지되며, 추후 이중전공 변경 기간 중 신청 가능
# 3. 2020년 2월 졸업예정자(4학년 수료_졸업대기 포함)는 반드시 1월초까지 이수구분변경신청을 하여 영역별 졸업 학점에 누락 되는 일이 없도록 해야 함
# 4. 이중전공 변경에 따라 성적 조회 후, 변경되지 않은 이수구분의 수정은 학사종합지원센터 내 1전공 소속 단과대학 창구에 방문하여 이수구분변경신청원을 작성하여 제출 하여야 함(방학 및 학기 중 가능)

# %%
# bias 조정 이후 참고

# %% [markdown]
# # sents를 어떻게 넣을 것인가

# %%
# 학사의 sents를 다 넣어보자!
# 코로나 count -> 6개라 안지우고 일단 해봄
haksa_corona_count = len(haksa_copy[haksa_copy['title'].str.contains('코로나19')])
# 결과 출력
print("코로나19가 포함된 데이터 개수:", haksa_corona_count)
print("삭제 전 데이터 개수:", len(haksa_copy))

haksa_filtered = haksa_copy[~haksa_copy['title'].str.contains('코로나')]
len(haksa_filtered)
# Out:
# 코로나19가 포함된 데이터 개수: 6
# 삭제 전 데이터 개수: 622
# 615

# %%
def preprocess(text):
    # 링크 제거 (http:// 또는 https:// 로 시작하는 링크)
    text = re.sub(r'https?://[\w\-.]+(?:/[\w\-./?=&%+]*)?', '', text)
    # Zoom 회의 참가 ID 제거 _ 작동안함
    text = re.sub(r'Zoom 회의 참가 ID \d{3} \d{3} \d{4}', '', text)
    # 전화번호 제거 (괄호 선택적으로)
    text = re.sub(r'\(?0\d{2,3}\)?[- ]?\d{3,4}[- ]?\d{4}', '', text)
    # 전번 제거
    text = re.sub(r'\d{2}-\d{4}-\d{4}', '', text)
    # 팩스번호 제거
    text = re.sub(r'FAX\.\d{2}-\d{3}-\d{4}', '', text)
    # 주소 제거
    text = re.sub(r'서울시 동대문구 이문로 107', '', text)
    # 이메일 제거
    text = re.sub(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b', '', text)
    # www 링크 제거
    text = re.sub(r'\b(?:https?://)?(?:www\.)?[-a-zA-Z0-9@:%._\+~#=]{2,256}\.[a-z]{2,6}\b', '', text)
    # hufs.ac.kr 링크 제거
    text = re.sub(r'hufs\.ac\.kr', '', text)
    #마지막 날짜 양식 변형
    text = re.sub(r'\d{4}\.\s\d{2}\.\s\d{2}\.', '', text)
    #마지막 날짜
    text = re.sub(r'\d{4}\.\s\d{2}\.', '', text) #과제 제출등에 유의
    # 문장부호 제거
    #text = re.sub(r'[,.:!?\\|※‘’”“→-○☏『』)(]', '', text)
    #text= re.sub(r'\n','',text)
    # 문장 리스트화 시 기준이 ., \n이 될 듯하여 안지우려함
    text = re.sub(r'[,:!?\\|※‘’”“→-○☏『』)(]', '', text)
    test= re.sub(r'\n\n\n\n\n','\n', text)
    text= re.sub(r'\n\n','\n',text)
    text = re.sub(r'\n \n', '\n', text)

    return text

# %%
haksa_filtered['cleaned_content'] = haksa_filtered['content'].apply(preprocess)
# Out:
# <ipython-input-20-0609ca7d9e43>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   haksa_filtered['cleaned_content'] = haksa_filtered['content'].apply(preprocess)

# %%
haksa_filtered.loc[2,'cleaned_content']
# Out:
# '\n2020학년도 전기 국제지역대학원 학석사연계과정 모집 안내\n2020학년도 전기 국제지역대학원학.석사 연계과정생을 모집하오니 관심있는 학생들의 신청을 바랍니다.\n1. 지원신청서 접수기간 \n 2020. 1. 20월 ~ 1. 23목 1500까지\n2. 접수처\n가. 서울캠퍼스 학사종합지원센터역사관 1층\n나. 글로벌캠퍼스 학사종합지원센터학생회관 1층\n 자세한 사항은 첨부 모집요강을 참고하여 주시기 바랍니다.\n2020. 1.\n양캠퍼스 학사종합지원센터 \n\n'

# %%
sentences = []

for i in range(10):  # 예시로 10번만 반복하도록 설정
    # '.'과 '\n' 기준으로 문장을 추출하여 리스트에 추가
    sentences.extend(haksa_filtered.loc[i, 'cleaned_content'].split('.'))
    sentences.extend(haksa_filtered.loc[i, 'cleaned_content'].split('\n'))

# 빈 문자열 제거
sentences = [sentence.strip() for sentence in sentences if sentence.strip()]
sentences = [sentence.replace('\n', '')]
#

# %%
for sent in sentences:
  print(sent)
  print()
# Out:
# [공통]이중전공변경 배정 확정 공고
# 2019학년도 제2학기 이중전공 변경 배정 결과를 아래와 같이 공고함
#
# 아 래
# 1
#
# 결과조회  종합정보시스템  전공/교직관리  이중전공 변경신청  안내사항
# 2
#
# 이중전공 변경 시에 배정된 학생은 추후 이중전공 변경 신청 불가
#  미배정된 학생은 기존 이수중인 이중전공/부전공이 유지되며 추후 이중전공 변경 기간 중 신청 가능
# 3
#
# 2020년 2월 졸업예정자4학년 수료_졸업대기 포함는 반드시 1월초까지 이수구분변경신청을 하여
#  영역별 졸업 학점에 누락 되는 일이 없도록 해야 함
# 4
#
# 이중전공 변경에 따라 성적 조회 후 변경되지 않은 이수구분의 수정은 학사종합지원센터 내
#  1전공 소속 단과대학 창구에 방문하여 이수구분변경신청원을 작성하여 제출 하여야 함방학 및 학기 중 가능
# 5
#
# 기타사항
# 1 부전공 전공심화+부전공 단일전공기존 이중전공/부전공 취소 신청기간
#  2020
#
# 1
#
# 29~1
#
# 31 종합정보시스템에서 신청1월 중순 학사공지 참조 바람
# 2 다음 학기 이중전공 변경기간은 5월초로 예정되어 있음
#
# 2020
#
# 1
# 교무처장
#
# [공통]이중전공변경 배정 확정 공고
#
# 2019학년도 제2학기 이중전공 변경 배정 결과를 아래와 같이 공고함.
#
# 아 래
#
# 1. 결과조회  종합정보시스템  전공/교직관리  이중전공 변경신청  안내사항
#
# 2. 이중전공 변경 시에 배정된 학생은 추후 이중전공 변경 신청 불가
#
# 미배정된 학생은 기존 이수중인 이중전공/부전공이 유지되며 추후 이중전공 변경 기간 중 신청 가능
#
# 3. 2020년 2월 졸업예정자4학년 수료_졸업대기 포함는 반드시 1월초까지 이수구분변경신청을 하여
#
# 영역별 졸업 학점에 누락 되는 일이 없도록 해야 함
#
# 4. 이중전공 변경에 따라 성적 조회 후 변경되지 않은 이수구분의 수정은 학사종합지원센터 내
#
# 1전공 소속 단과대학 창구에 방문하여 이수구분변경신청원을 작성하여 제출 하여야 함방학 및 학기 중 가능
#
# 5. 기타사항
#
# 1 부전공 전공심화+부전공 단일전공기존 이중전공/부전공 취소 신청기간
#
# 2020.1.29~1.31 종합정보시스템에서 신청1월 중순 학사공지 참조 바람
#
# 2 다음 학기 이중전공 변경기간은 5월초로 예정되어 있음.
#
# 2020. 1
#
# 교무처장
#
# 2020학년도 1학기 수강신청 공고 2020학년도 제1학기 수강신청에 대하여 아래와 같이 공고합니다
#
# - 아  래 -1
#
# 강의시간표·강의계획서 조회 및 수강편람 열람 가
#
# 강의시간표 및 강의계획서 조회  학교 홈페이지  Hot Link <강의시간표 조회> 변동사항이 실시간으로 반영되므로 수강신청 전 다시 확인바람
#
# 나
#
# 수강편람 열람  학교 홈페이지  Hot Link <수강편람> 수강편람은 매 학기 수강신청 전 학교 홈페이지 Hot Link에 게시 1월말 예정2
#
# 수강신청 일정  2019-2학기부터 장바구니 명칭 변경  예비수강신청함구 분일 정비 고예비수강신청함구장바구니2020
#
# 1
#
# 29수 1000 ~ 수강신청 변경 종료시까지학교홈페이지
#
# krHot Link 수강신청/예비수강신청함바로가기수강신청재학생4학년2020
#
# 2
#
# 3월 1000 ~ 15003학년2020
#
# 2
#
# 4화 1000 ~ 15002학년2020
#
# 2
#
# 5수 1000 ~ 15001학년2020
#
# 2
#
# 6목 1000 ~ 1500전체 학년2020
#
# 2
#
# 7금 1000 ~ 1500신·편입생2020
#
# 3
#
# 9월 1000 ~ 1600수강신청 변경2020
#
# 3
#
# 16월 ~ 3
#
# 20금 매일 1000 ~ 1600  가
#
# 본인의 1전공 학년 기준 수강일자에 1전공 및 이중부전공 수강신청나
#
# 수강신청학년  수강신청 전 예비수강신청함에 로그인하여 필히 사전 확인 2020-1학기 등록횟수 기준4학년등록 7회 이상 3학년등록 5~6회2학년등록 3~4회 1학년등록 1~2회다
#
# 기타안내신편입생 및 외국인 교환학생 외국인 방문학생 입학한 첫 학기 재수강 신청 불가 2020-1학기 복학예정자복학 신청 전 수강신청 기간에 수강신청 가능2020-1학기 휴학신청자수강신청 전 휴학신청수강신청 로그인 불가수강신청 후 휴학신청휴학 승인 시 수강신청 과목 일괄 삭제됨
#
# 라
#
# 수강신청 기간[2020
#
# 2
#
# 3월 ~ 2
#
# 7금] 종료 후 수강인원 0명 강좌 자동 폐강전공 2학년 이상 수업에서만 실시3
#
# 수강신청 방법방 법내 용예비수강신청함 활용- 학교 홈페이지  Hot Link <예비수강신청함 바로가기>로 로그인- 수강희망과목을 선택하여 예비수강신청함에 담기최대 15강좌- 수강신청기간에 예비수강신청함 목록에서 수강할 과목을 선택하여 수강신청과목별 조회신청- 학교 홈페이지  Hot Link <수강신청 또는 수강신청 변경 바로가기>로 로그인- 전공 이중부전공 교양 등 영역별로 개설 과목을 조회하여 한 과목씩 수강신청- 과목조회 신청은 수강신청변경기간 중에만 이용할 수 있음
#
# 모바일 앱 수강신청 서비스 종료  2017-2학기부터 어플리케이션 사용 불가 수강신청 대기 순번 시스템 도입  자세한 사항은 붙임 파일 참조 - 접속자가 많은 경우 로그인 및 수강신청 모든 요청에 대기 순번을 발급하고 순차적으로 서비스 함
#
# - 유의사항  대기 순번을 부여받은 후 새로고침F5을 하거나 메뉴를 반복 클릭하면 최후 번호로 재발급되어 대기시간이 늘어남
#
# 예비수강신청함 시스템 사용법모의 동영상 QR코드  수강신청 시스템 사용법 모의 동영상 QR코드 4 수강신청 유의사항  자세한 사항은 수강편람 참조가
#
# 수강신청 기간 중 반드시 학생 본인이 하여야 함
#
# 수강신청 전 본인 종합정보시스템의 비밀번호 변경 권장나
#
# 강좌별 비고란의 개설학과의 수강생 안내수강대상 및 수강허용/제한 확인 자세한 사항은 해당학과 문의서울캠퍼스클릭 글로벌캠퍼스클릭다
#
# 수강금지과목 수강 불가  동일과목 학수번호 앞6자리가 같은 과목 또는 학과에서 지정한 과목의 경우  학과 간 중복수강금지과목으로 지정된 과목의 경우  학과전공별 수강금지 교양교과목의 경우라
#
# 타캠퍼스 개설 교과목 수강 1 타캠퍼스 학과의 전공을 이중부전공으로 이수허가 받은 학생에 한하여 타캠퍼스 해당 이중부전공 과목 수강신청 가능단 교양 자유선택 수강 불가 2 단 아래의 경우 수강 가능한 개설캠퍼스 유의1전공 캠퍼스이수중인 타캠퍼스 이중부전공전공구분수강신청서울캠퍼스철학 사학 언어인지과학과부전공서울캠퍼스글로벌캠퍼스정치외교학 행정학 언론
#
# 정보 광고
#
# PR
#
# 브랜딩 방송
#
# 영상
#
# 뉴미디어부전공글로벌캠퍼스이중전공양캠퍼스마
#
# 수강신청한 과목을 매매 또는 거래하였을 경우 학생징계규정에 의해 징계의 사유가 될 수 있으니 유념하기 바람
#
# 바
#
# 학사운영의 투명성 및 공정성을 제고하기 위해 교수-자녀 간 강의 수강을 지양하기 바람
#
# 사
#
# 변경 취소 등 최종 완료 후 본인의 시간표 확인 권장
#
# 아
#
# 수강신청변경한 과목을 e-Class로 바로 불러오는 방법 안내  e-Class 로그인   마이페이지   개인정보   [동기화] 클릭  5
#
# 수강신청 변경기간2020
#
# 3
#
# 16월 ~ 3
#
# 20금 1000~1600방법학교 홈페이지     수강신청/장바구니 바로가기에서 신청 수강신청 변경 후 본인의 강의시간표 반드시 확인6
#
# 폐강 공고1차 폐강공고수강신청 0명 강좌2020
#
# 2
#
# 10월 또는 2
#
# 11화 예정단 전공 2학년 이상 수업에서만 실시홈페이지 학사공지 게시2차 폐강공고2020
#
# 3
#
# 25수 오전 예정대체 수강신청2020
#
# 3
#
# 25수 ~ 3
#
# 27금 1600 학사종합지원센터 자세한 사항은 추후 폐강 공고 참조7
#
# 재수강과목 연결기간2020
#
# 3
#
# 25수 ~ 3
#
# 27금 매일 1000~1700방법학교 홈페이지  종합정보시스템  수업/수강관리  재수강과목선택이전 취득성적 조회 후 재수강 대상 성적 선택 자세한 사항은 수강편람의 재수강 안내 참조8
#
# 수강신청 취소기간2020
#
# 3
#
# 30월 ~ 3
#
# 31화 매일 1000~2200방법학교 홈페이지    수강신청취소 바로가기에서 신청 수강신청 취소 후 본인의 강의시간표 반드시 확인1 12학점 미만으로 취소 불가단 4학년은 예외이나 전체 과목을 취소할 수는 없음2 수강신청은 12학점 미만으로 가능하나 이 경우 수강 취소 불가9
#
# 2020학년도 제1학기 개강  2020
#
# 3
#
# 16월10
#
# 수강신청 관련 FAQ질문답변제한인원 증원 여부전공각 학과에서 증원여부 결정 및 시스템 증원 처리 해당학과 문의서울캠퍼스클릭 글로벌캠퍼스클릭교양증원 불가온라인으로 수강신청하지 못한 과목을 교수님께 허락사인받아 수강할 수 있는지 여부불가 모든 과목은 수강신청 및 변경기간에 학생 본인이 온라인으로 수강신청을 완료하여야 합니다
#
# 제한인원이 꽉 찬 전공이중/부전공 과목을 담당 교수님이 구두로 수강 허용하는 경우에도 반드시 해당 학과의 수업 담당 조교가 제한 인원을 늘려주어 학생이 온라인 수강신청을 완료하여야 합니다
#
# 강의시간표 비고 내용 및수강신청 허용/제한 문의 해당학과 문의서울캠퍼스클릭 글로벌캠퍼스클릭붙임 1
#
# 대기순번제 수강생 유의사항 1부붙임 2
#
# 학과 사무실 및 학사종합지원센터 안내 1부2020
#
# 1
#
# 서울·글로벌캠퍼스 교무처장
#
#
# 조회
#  종합정보시스템 -> 성적/학점/졸업관리 -> 졸업예비사정 결과 조회
# 2
#
# 기준 시점  2020
#
# 1
#
# 30기준
# 3
#
# 유의사항
#  - 미비사항없음졸업요건완료 학생도 계절학기 재수강 과목 F로 졸업이 불가할 수 있음
#  - 사범대/비사범대교직이수자  미비사항없음이 교원자격증 취득이 가능하다는 의미는 아님
# 교원자격증 취득 관련  사범대/교직 담당자에게 문의
#  -학과에서 제출한 졸업시험 및 논문 단과대학 교학과에 제출한 외국어인증은 기준 시점까지
# 모두 반영되었으므로 이상이 있을 경우 반드시 학과 및 단과대학 교학과 문의
# - 중국어대학의 경우 FLEX+졸업논문+학과졸업신청서의 이수내역 심사가 모두 합격하여야 반영되므로 논문만 제출한 경우 졸업시험/논문 내역이 반영되지 않음
# - 중국어대학의 경우 특기자여부 등을 파악하기 어려우므로 반드시 학과에 학과졸업신청서 작성시 이상유무를 확인하기 바람
#
# - 재학연한초과제적예정이라고 표기된 학생은 이번에 졸업하지 않을 시 제적되는 학생이므로
# 반드시 졸업요건을 완료하여 졸업하기 바람
#
# - 미이수 내역에 전공필수미비 또는 이중전공필수미비 중 본인이 이상이 없다고 판단되는 경우 학과사무실 방문하여 확인을 받고 이상이 없는 경우 이상이 없음을 확인하는 서류를 받아 학사종합지원센터에 제출하여야 미비내역이 없어짐
#
# 1
#
# 졸업에 필요한 미비조건 완료
# 2
#
# 수료졸업대기 조건 완료
#  *졸업학점만 완료하면 수료졸업대기 가능 학점체크 하면 됨
#
# 외국어인증이나 졸업논문시험 미비상태로 결과조회되면 됨
#  반드시 1
#
# 31금 오후 3시까지 미비 조건을 완료하여야 함
#
# 단 외국어연수평가원 방학 특별과정 이수자는 해당 과정 종료일 당일
# 수료증 제출자에한하여 졸업 또는 수료처리 가능
#
# 당일 미제출 시 졸업 또는 수료처리 불가
#
# 4
#
# 추가 확인 필요 사항
# -이중전공/부전공 등이 필수가 아닌 학생예  편입생 06학번 이전 입학생 중 기존에 이중/제2/부전공 등을 신청하였으나 이수를 희망하지 않는 경우 반드시 학사종합지원센터 방문 후1
#
# 28오후3시 까지 취소하여야만 졸업 또는 수료가 가능함
#
# - 이수구분 수정교류과목 자선->전공 전공인정 교양과목->전공 등을 하지 않아 학점이 미비 된 학생은 반드시 학사종합지원센터 방문 후 이수구분 수정을 하여야 졸업 또는 수료가 가능함
#
# 단 이번 계절학기 수강내역에 관하여는 계절학기 성적반영일 당일까지 처리하여야 함
#
# - 이중전공을 부전공/ 전공심화+부전공/ 전공심화단일전공으로 변경하면 학점이 완료되어 졸업 또는 수료졸업대기가 가능한 학생은 반드시 학사종합지원센터 방문 후 변경하여야만 졸업 또는 수료졸업대기가 가능함
#
# -코어사업 중 지역학사/지역전문가과정/학석사연계과정 신청자 중 이번 졸업 또는 수료학점
# 완료 후 졸업을 미룬 상태를 희망하는 학생은 첨부된 서식을 작성하여 학과 확인을 받은
# 후 학사종합지원센터에 1
#
#
# 1
#
# 일정  2020
#
# 2
#
# 3월 ~ 2
#
# 7금2
#
# 방법  [종합정보시스템] 로그인  [휴/복학 신청]3
#
# 유의사항 가
#
# 일반 휴학 - 휴학은 1년 단위로 신청 단 1개 학기 이후 복학 가능 - 휴학기간 만료 후 다시 휴학신청 가능하며 재학 중 3년을 초과할 수 없음 단 2012년 2학기 이후 3학년으로 편입학한 학생은 2년을 초과할 수 없음  휴학기간 만료 후 복학하지 않을 경우 휴학기간초과제적됨 - 신·편입생 재입학생의 첫 학기 휴학 불가 단 질병으로 인해 4주 이상 치료를 요하는 경우에 한해서 일반휴학을 허가할 수 있음
#
# 별도문의 - 수업일수 1/4선 이후 아래의 경우에 한해서만 휴학을 허가하고 등록금 차액은 환불함  질병 또는 입원으로 인하여 4주 이상의 치료를 요하는 경우  3/4선까지만 허용 종합병원에서 발급받은 4주 이상 입원진단서 또는 4주 이상 수업참여가 어렵다는 의사소견진단서 제출  학업을 계속할 수 없는 명백한 사유가 있는 경우  중간고사 전 주 금요일까지만 허용 공식적인 서류로 사유를 증명할 수 있어야 함  증빙서류 미비 또는 요건 미충족 시 허가하지 않음 - 일반 휴학 중 입대할 경우 군입대 휴학으로 재신청하여야 함미처리 시 일반 휴학기간 종료 후 제적처리 됨 - 등록 휴학  휴학신청기간에 휴학 신청 후 등록기간에 등록금 납부 시 자동 처리됨 나
#
# 군입대 휴학 - 입대일 이전 학교 종합정보시스템에서 신청 후 입영통지서 사본 제출 이메일  군입대 휴학자 중 장기복무자는 입영통지서 제출 시 또는 장기확정 시 필히 구두로 신고하여야 함 - 휴학기간  입영일부터 전역일까지 귀향조치 시 관련 증빙서류 제출 후 조치 요망 - 전역일 이후 계속 휴학을 원하는 경우 복학예정일이 남아있더라도 일반 휴학으로 전환하여야 함 전역일이 기재되어있는 증빙서류 제출 - 1/4선 후~3/4선 이전 입대 예정자는 일반 휴학 신청 후 군입대 휴학으로 재신청 하여야 함 - 3/4선 후 입대 예정자가 금학기 재학할 경우 해당 학기 성적 인정 절차를 진행하고 입대하여야 함 인정 절차 미이행 시 당해학기 성적 0
#
# 00 및 학사경고 처리 - 3/4선 후 입대 예정자가 금학기 일반 휴학일 경우 일반 휴학은 사용한 것으로 처리됨 다
#
# 모성보호 휴학 - 임신
#
# 출산
#
# 육아 관련 휴학 희망자는 학사종합지원센터 별도 문의 바람 라
#
# 창업휴학 - 창업휴학 희망자는 창업교육센터로 별도 문의 바람 - 창업교육센터  서울  / 글로벌 ~2 마
#
# 복학 - 휴학 후 복학할 경우 반드시 복학신청을 하여야 함 1개 학기 휴학자도 복학신청 가능  일반휴학을 1년 사용하여 복학예정일이 2020학년도 1학기라고 하더라도 복학신청을      반드시 하여야 함자동 복학처리되지 않음 - 복학생은 소정의 기간 내에 등록금 납부등록휴학자 제외 및 수강신청을 하여야 함 - 군입대 휴학자는 신청기간에 인터넷으로 복학신청 후 전역 증빙서류전역자  전역증 사본 또는 병적증명서 또는 복무확인서 
정자가 금학기 재학할 경우 해당 학기 성적 인정 절차를 진행하고 입대하여야 함 인정 절차 미이행 시 당해학기 성적 0.00 및 학사경고 처리 - 3/4선 후 입대 예정자가 금학기 일반 휴학일 경우 일반 휴학은 사용한 것으로 처리됨 다. 모성보호 휴학 - 임신.출산.육아 관련 휴학 희망자는 학사종합지원센터 별도 문의 바람 라. 창업휴학 - 창업휴학 희망자는 창업교육센터로 별도 문의 바람 - 창업교육센터  서울  / 글로벌 ~2 마. 복학 - 휴학 후 복학할 경우 반드시 복학신청을 하여야 함 1개 학기 휴학자도 복학신청 가능  일반휴학을 1년 사용하여 복학예정일이 2020학년도 1학기라고 하더라도 복학신청을      반드시 하여야 함자동 복학처리되지 않음 - 복학생은 소정의 기간 내에 등록금 납부등록휴학자 제외 및 수강신청을 하여야 함 - 군입대 휴학자는 신청기간에 인터넷으로 복학신청 후 전역 증빙서류전역자  전역증 사본 또는 병적증명서 또는 복무확인서 전역예정자  전역예정증명서 또는 전역예정일이 나와있는 복무확인서 이메일 제출스캔 또는 폰사진-입영일과 전역일이 잘 보이도록 촬영 바람수업일수 1/4선 이전 전역자 복학 가능 이후 전역자 별도 문의바람  학생예비군은 별도로 신청해야 함학교 종합정보시스템로그인복학 및 예비군대신청 작성  신청- 휴학 후 복학할때마다 다시 신청해야 함- 예비군연대  서울 / 글로벌 4119   바. 기타사항 - 휴·복학 승인 후 취소 또는 변경 시에는 1/4선 이전 방문 신청만 가능하므로 신중하게 신청 할 것 - 금 학기 휴학 신청 시 기존 수강신청 데이터는 삭제됨 이후 수강신청 하지 말 것 - 서류제출  서울캠퍼스 글로벌캠퍼스   이메일 송부 시 첨부 서류입영통지서 및 전역일자 기재 된 증빙서류 빈공간에 반드시 학과 학번 연락처를 명기하기 바람  이메일 제목작성 방법  이름_학과_학번 - 등록금 납부 일정 및 등록관련 사항은 재무회계팀에 문의하기 바람2020. 1.교무처장
#
# [공통] 부전공 신청 및 이중전공/부전공 취소 일정 공고
#
# 2020학년도 1학기 부전공 신청 및 이중전공/부전공 취소 일정을 아래와 같이 공고함
#
# - 아 래 -
# 1
#
# 대상  2019학년도 2학기 기준 2학기~7학기 재학/휴학생 중 부전공 희망자 또는 이중전공/부전공 취소 희망자단일전공 이수 희망자
#  8학기 이상인 학생은 학사종합지원센터 방문 신청
# 2
#
# 일정
#
#
# 구 분
# 일시
# 비고
#
# 신청기간
# 2020
#
# 1
#
# 29수10시~1
#
# 31금12시
# 종합정보시스템
#
# 결과확인
# 2020
#
# 1
#
# 31금 18시
# 종합정보시스템
#  부전공 신청시 기존 이중전공 또는 부전공은 자동삭제 됨
# 신청기간이후추가신청및변경절대불가
# 3
#
# 방법
# 가
#
# 부전공신청종합정보시스템->전공/교직관리->전공심화+부전공/부전공신청
# 나
#
# 이중전공/부전공취소단일전공희망자종합정보시스템->전공/교직관리->이중전공/부전공취소
# 4
#
# 유의사항
# 가
#
# 국가리더전공융합전공의 부전공 이수 가능국가리더전공을 제외한 융합전공은 부전공 신청 불가
# 나
#
# 부전공 신청 시 전공심화+부전공 또는 부전공 중 선택 가능전공이수제도 변경 관련 첨부 PPT참고
#  참고 기존 전공심화+A학과부전공 이수자가 전공심화 없이 A학과부전공을 이수하고자 할 경우
# 부전공 클릭 후 A학과로 신청하여야 함
# 다
#
# 이중전공/부전공 취소단일전공 희망자를 신청한 학생은 전공을 심화하여 이수하여야 함
# 단 편입생 및 2015학번이후 순수외국인전형 입학생사범대생 제외은 전공심화 불필요
#  전공심화 시 1전공 졸업 이수학점은 학번별/단과대학별 상이하므로 소속캠퍼스 수강편람 참고
# 라
#
# 외국어로서의한국어교육전공및외국어로서의한국어통번역전공은입학전형기준외국인전형입학생만
# 가능하며외국어로서의한국어통번역전공은2018학번부터만신청가능
# 마
#
# 비사범대학학생의사범대학학과로의신청불가
# 바
#
# LDLT사회과학전공LD학부서울캠퍼스영어통번역학과15학번이후EICC학과는가능글로벌캠퍼스영어통번역학부Tesol영어학은신청가능
#  국제경영학과경제학과경영정보학과로의신청불가
# 사
#
# 양캠퍼스서울 / 글로벌에서 이수한 이중전공부전공과목에 대해 이중전공부전공 취소 또는 변경 시 캠퍼스가 변경된 경우 변경 된 캠퍼스에서 재수강 불가
#  변경전 서울 / 글로벌 캠퍼스 이중전공부전공이 유지되어 있는 상태에서 재수강을 완료해야 함
#
# 2020
#
# 1
# 교무처장
#
# [공통] 부전공 신청 및 이중전공/부전공 취소 일정 공고
#
# 2020학년도 1학기 부전공 신청 및 이중전공/부전공 취소 일정을 아래와 같이 공고함.
#
# - 아 래 -
#
# 1. 대상  2019학년도 2학기 기준 2학기~7학기 재학/휴학생 중 부전공 희망자 또는 이중전공/부전공 취소 희망자단일전공 이수 희망자
#
# 8학기 이상인 학생은 학사종합지원센터 방문 신청
#
# 2.일정
#
# 구 분
#
# 일시
#
# 비고
#
# 신청기간
#
# 2020.1.29수10시~1.31금12시
#
# 종합정보시스템
#
# 결과확인
#
# 2020.1.31금 18시
#
# 종합정보시스템
#
# 부전공 신청시 기존 이중전공 또는 부전공은 자동삭제 됨
#
# 신청기간이후추가신청및변경절대불가
#
# 3.방법
#
# 가.부전공신청종합정보시스템->전공/교직관리->전공심화+부전공/부전공신청
#
# 나.이중전공/부전공취소단일전공희망자종합정보시스템->전공/교직관리->이중전공/부전공취소
#
# 4. 유의사항
#
# 가. 국가리더전공융합전공의 부전공 이수 가능국가리더전공을 제외한 융합전공은 부전공 신청 불가
#
# 나. 부전공 신청 시 전공심화+부전공 또는 부전공 중 선택 가능전공이수제도 변경 관련 첨부 PPT참고
#
# 참고 기존 전공심화+A학과부전공 이수자가 전공심화 없이 A학과부전공을 이수하고자 할 경우
#
# 부전공 클릭 후 A학과로 신청하여야 함
#
# 다. 이중전공/부전공 취소단일전공 희망자를 신청한 학생은 전공을 심화하여 이수하여야 함
#
# 단 편입생 및 2015학번이후 순수외국인전형 입학생사범대생 제외은 전공심화 불필요
#
# 전공심화 시 1전공 졸업 이수학점은 학번별/단과대학별 상이하므로 소속캠퍼스 수강편람 참고
#
# 라.외국어로서의한국어교육전공및외국어로서의한국어통번역전공은입학전형기준외국인전형입학생만
#
# 가능하며외국어로서의한국어통번역전공은2018학번부터만신청가능
#
# 마.비사범대학학생의사범대학학과로의신청불가
#
# 바.LDLT사회과학전공LD학부서울캠퍼스영어통번역학과15학번이후EICC학과는가능글로벌캠퍼스영어통번역학부Tesol영어학은신청가능
#
# 국제경영학과경제학과경영정보학과로의신청불가
#
# 사. 양캠퍼스서울 / 글로벌에서 이수한 이중전공부전공과목에 대해 이중전공부전공 취소 또는 변경 시 캠퍼스가 변경된 경우 변경 된 캠퍼스에서 재수강 불가
#
# 변경전 서울 / 글로벌 캠퍼스 이중전공부전공이 유지되어 있는 상태에서 재수강을 완료해야 함.
#
# 2020. 1
#
# 교무처장
#
# 2020학년도 1학기 재입학 허가 공고
# 2020학년도 제1학기 재입학 허가자를 공고합니다
#
# 1
#
# 재입학 허가 여부 확인  인터넷 종합정보시스템 확인
# 종합정보시스템 로그인학적변동신청재입학신청에서 결재 여부 확인
# 2
#
# 등록기간  2020
#
# 2월 중순예정별도공고
# 3
#
# 등록방법  학교 홈페이지에서 등록금 고지서 출력 후 가상계좌 입금
# 4
#
# 수강신청  2020
#
# 2
#
# 3월 ~ 2
#
# 7금 학년별 세부신청기간은 별도 공지 참조
# 5
#
# 유의사항
# 가
#
# 반드시 등록기간을 엄수하여야 하며 기간 내에 등록하지 아니한 학생은 재입학 자격을 상실함
#  추가등록 분할납부 없음
#
# 9학기 이상 감면신청자 및 학자금대출 희망자 별도 문의 후 기간 내 납부
# 나
#
# 제적종별에 따라 재입학 횟수가 1회 또는 2회로 제한되므로 재차 제적되는 일이 없도록 유의할 것
# 다
#
# 수강신청은 학교 홈페이지에서 수강신청 기간의 학년별 일정에 따라 시행함
#  강의시간표 및 수강편람  홈페이지 중앙하단 HUFS Service 참조
#  라
#
# 기존 졸업시험/논문 합격 기록은 삭제됨
# 마
#
# 재입학 학생은 학칙 및 재입학 시행 규정을 반드시 참조 바람
#  홈페이지학교정보학교소개현황전자규정집
# 2020
#
# 1
#
# 교무처장
#
# 2020학년도 1학기 재입학 허가 공고
#
# 2020학년도 제1학기 재입학 허가자를 공고합니다.
#
# 1. 재입학 허가 여부 확인  인터넷 종합정보시스템 확인
#
# 종합정보시스템 로그인학적변동신청재입학신청에서 결재 여부 확인
#
# 2. 등록기간  2020. 2월 중순예정별도공고
#
# 3. 등록방법  학교 홈페이지에서 등록금 고지서 출력 후 가상계좌 입금
#
# 4. 수강신청  2020. 2. 3월 ~ 2. 7금 학년별 세부신청기간은 별도 공지 참조
#
# 5. 유의사항
#
# 가. 반드시 등록기간을 엄수하여야 하며 기간 내에 등록하지 아니한 학생은 재입학 자격을 상실함
#
# 추가등록 분할납부 없음. 9학기 이상 감면신청자 및 학자금대출 희망자 별도 문의 후 기간 내 납부
#
# 나. 제적종별에 따라 재입학 횟수가 1회 또는 2회로 제한되므로 재차 제적되는 일이 없도록 유의할 것
#
# 다. 수강신청은 학교 홈페이지에서 수강신청 기간의 학년별 일정에 따라 시행함
#
# 강의시간표 및 수강편람  홈페이지 중앙하단 HUFS Service 참조
#
# 라. 기존 졸업시험/논문 합격 기록은 삭제됨
#
# 마. 재입학 학생은 학칙 및 재입학 시행 규정을 반드시 참조 바람
#
# 홈페이지학교정보학교소개현황전자규정집
#
# 2020. 1.
#
# 교무처장
#
# 글로벌 지역학 과정 신청 안내
#
# 2020-1학기 글로벌 지역학 과정지역전문가과정 지역학사과정 신청변경 및 취소 포함 일정을 아래와 같이 공고합니다
#
# 글로벌 지역학 과정이란 세계 각 지역에 대한 총체적이고 다면적인 이해 능력을 배양하여 국가경영전략 및 기업의 해외시장진출과 국제 비즈니스 수행에 필요한 전문가 양성을 목표로 운영되는 교육과정
# 1
#
# 대상 아래 표의 학과 전공/이중전공 재학생 및 휴학생
#
#
#  지역학과정 이수 가능 학과
# 서울캠퍼스 학과
#  EU 지역 프랑스어학부 독일어과 이탈리아어과 네덜란드어과 스칸디나비아어과
#  러시아·중앙아시아 지역 노어과 터키·아제르바이잔어과 몽골어과
#  중남미 지역 스페인어과 포르투갈어과
#  인도·동남아 지역 말레이인도네시아어과 베트남어과 태국어과 인도어과
#  중동·북아프리카 지역 아랍어과 이란어과
# 글로벌캠퍼스 학과
#  EU 지역 그리스·불가리아학과
#  동유럽지역 동유럽학대학 소속 전학과
#  중남미 지역 스페인어통번역학과
#  중동·북아프리카 지역 아랍어통번역학과
# 2
#
# 신청기간 2020
#
# 2
#
# 3월 ~ 3
#
# 6금
# 3
#
# 방법 종합정보시스템 -> 전공/교직관리 -> 지역학과정 신청취소 관리
# 4
#
# 지역학과정 수료시 학위 수여
# 가
#
# 지역전문가과정 문학사지역전문가과정 이수로 표기됨
# 나
#
# 지역학사과정 문학사 대신 지역학사 학위가 수여됨
# 다
#
# 졸업에 필요한 졸업논문이나 졸업종합시험 등 기타 졸업 요건은 학과 관련 규정에 의함
#
# 라
#
# 글로벌 지역학 과정에 대한 자세한 사항은 수강편람을 참고하여 주시기 바랍니다
#
# 서울캠퍼스 수강편람  제67쪽 이하
# 글로벌캠퍼스 수강편람  제54쪽 이하
# 2020
#
# 1
#
# 교무처장
#
# 글로벌 지역학 과정 신청 안내
#
# 2020-1학기 글로벌 지역학 과정지역전문가과정 지역학사과정 신청변경 및 취소 포함 일정을 아래와 같이 공고합니다.
#
# 글로벌 지역학 과정이란 세계 각 지역에 대한 총체적이고 다면적인 이해 능력을 배양하여 국가경영전략 및 기업의 해외시장진출과 국제 비즈니스 수행에 필요한 전문가 양성을 목표로 운영되는 교육과정
#
# 1. 대상 아래 표의 학과 전공/이중전공 재학생 및 휴학생
#
# 지역학과정 이수 가능 학과
#
# 서울캠퍼스 학과
#
# EU 지역 프랑스어학부 독일어과 이탈리아어과 네덜란드어과 스칸디나비아어과
#
# 러시아·중앙아시아 지역 노어과 터키·아제르바이잔어과 몽골어과
#
# 중남미 지역 스페인어과 포르투갈어과
#
# 인도·동남아 지역 말레이인도네시아어과 베트남어과 태국어과 인도어과
#
# 중동·북아프리카 지역 아랍어과 이란어과
#
# 글로벌캠퍼스 학과
#
# EU 지역 그리스·불가리아학과
#
# 동유럽지역 동유럽학대학 소속 전학과
#
# 중남미 지역 스페인어통번역학과
#
# 중동·북아프리카 지역 아랍어통번역학과
#
# 2. 신청기간 2020. 2. 3월 ~ 3. 6금
#
# 3. 방법 종합정보시스템 -> 전공/교직관리 -> 지역학과정 신청취소 관리
#
# 4. 지역학과정 수료시 학위 수여
#
# 가. 지역전문가과정 문학사지역전문가과정 이수로 표기됨
#
# 나. 지역학사과정 문학사 대신 지역학사 학위가 수여됨
#
# 다. 졸업에 필요한 졸업논문이나 졸업종합시험 등 기타 졸업 요건은 학과 관련 규정에 의함.
#
# 라. 글로벌 지역학 과정에 대한 자세한 사항은 수강편람을 참고하여 주시기 바랍니다.
#
# 서울캠퍼스 수강편람  제67쪽 이하
#
# 글로벌캠퍼스 수강편람  제54쪽 이하
#
# 2020. 1.
#
# 교무처장

# %% [markdown]
# ### textrank하는 함수

# %%
sents = sentences
sents = [sent for sent in sents if sent is not None]
sents =sents[260:270]

# %%
n = 260
for sent in sents:
  print(n, sent)
  n+=1
# Out:
# 260 창업휴학 - 창업휴학 희망자는 창업교육센터로 별도 문의 바람 - 창업교육센터  서울  / 글로벌 ~2 마
# 261 복학 - 휴학 후 복학할 경우 반드시 복학신청을 하여야 함 1개 학기 휴학자도 복학신청 가능  일반휴학을 1년 사용하여 복학예정일이 2020학년도 1학기라고 하더라도 복학신청을      반드시 하여야 함자동 복학처리되지 않음 - 복학생은 소정의 기간 내에 등록금 납부등록휴학자 제외 및 수강신청을 하여야 함 - 군입대 휴학자는 신청기간에 인터넷으로 복학신청 후 전역 증빙서류전역자  전역증 사본 또는 병적증명서 또는 복무확인서 전역예정자  전역예정증명서 또는 전역예정일이 나와있는 복무확인서 이메일 제출스캔 또는 폰사진-입영일과 전역일이 잘 보이도록 촬영 바람수업일수 1/4선 이전 전역자 복학 가능 이후 전역자 별도 문의바람  학생예비군은 별도로 신청해야 함학교 종합정보시스템로그인복학 및 예비군대신청 작성  신청- 휴학 후 복학할때마다 다시 신청해야 함- 예비군연대  서울 / 글로벌 4119   바
# 262 기타사항 - 휴·복학 승인 후 취소 또는 변경 시에는 1/4선 이전 방문 신청만 가능하므로 신중하게 신청 할 것 - 금 학기 휴학 신청 시 기존 수강신청 데이터는 삭제됨 이후 수강신청 하지 말 것 - 서류제출  서울캠퍼스 글로벌캠퍼스   이메일 송부 시 첨부 서류입영통지서 및 전역일자 기재 된 증빙서류 빈공간에 반드시 학과 학번 연락처를 명기하기 바람  이메일 제목작성 방법  이름_학과_학번 - 등록금 납부 일정 및 등록관련 사항은 재무회계팀에 문의하기 바람2020
# 263 1
# 264 교무처장
역일이 잘 보이도록 촬영 바람수업일수 1/4선 이전 전역자 복학 가능 이후 전역자 별도 문의바람  학생예비군은 별도로 신청해야 함학교 종합정보시스템로그인복학 및 예비군대신청 작성  신청- 휴학 후 복학할때마다 다시 신청해야 함- 예비군연대  서울 / 글로벌 4119   바. 기타사항 - 휴·복학 승인 후 취소 또는 변경 시에는 1/4선 이전 방문 신청만 가능하므로 신중하게 신청 할 것 - 금 학기 휴학 신청 시 기존 수강신청 데이터는 삭제됨 이후 수강신청 하지 말 것 - 서류제출  서울캠퍼스 글로벌캠퍼스   이메일 송부 시 첨부 서류입영통지서 및 전역일자 기재 된 증빙서류 빈공간에 반드시 학과 학번 연락처를 명기하기 바람  이메일 제목작성 방법  이름_학과_학번 - 등록금 납부 일정 및 등록관련 사항은 재무회계팀에 문의하기 바람2020. 1.교무처장
# 266 [공통] 부전공 신청 및 이중전공/부전공 취소 일정 공고
#
# 2020학년도 1학기 부전공 신청 및 이중전공/부전공 취소 일정을 아래와 같이 공고함
# 267 - 아 래 -
# 1
# 268 대상  2019학년도 2학기 기준 2학기~7학기 재학/휴학생 중 부전공 희망자 또는 이중전공/부전공 취소 희망자단일전공 이수 희망자
#  8학기 이상인 학생은 학사종합지원센터 방문 신청
# 2
# 269 일정
#
#
# 구 분
# 일시
# 비고
#
# 신청기간
# 2020

# %%
print(sents[9])
sents[9]
# Out:
# 일정
#
#
# 구 분
# 일시
# 비고
#
# 신청기간
# 2020
# '일정\n\n\n구 분\n일시\n비고\n\n신청기간\n2020'

# %%
from textrank import KeywordSummarizer

keyword_extractor = KeywordSummarizer(
    tokenize = komoran_tokenize,
    window = -1,
    verbose = False
)

keywords = keyword_extractor.summarize(sents, topk=30)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/_jpype.cpython-310-x86_64-linux-gnu.so in kr.co.shineware.nlp.komoran.model.KomoranResult.getTokenList()
#
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.NullPointerException            Traceback (most recent call last)
# <ipython-input-34-d37675328116> in <cell line: 9>()
#       7 )
#       8
# ----> 9 keywords = keyword_extractor.summarize(sents, topk=30)
#
# /content/textrank/textrank/summarizer.py in summarize(self, sents, topk)
#      98             Each tuple stands for (word, rank)
#      99         """
# --> 100         self.train_textrank(sents)
#     101         return self.keywords(topk)
#     102
#
# /content/textrank/textrank/summarizer.py in train_textrank(self, sents, bias)
#      59         """
#      60
# ---> 61         g, self.idx_to_vocab = word_graph(sents,
#      62             self.tokenize, self.min_count,self.window,
#      63             self.min_cooccurrence, self.vocab_to_idx, self.verbose)
#
# /content/textrank/textrank/word.py in word_graph(sents, tokenize, min_count, window, min_cooccurrence, vocab_to_idx, verbose)
#      34     """
#      35     if vocab_to_idx is None:
# ---> 36         idx_to_vocab, vocab_to_idx = scan_vocabulary(sents, tokenize, min_count)
#      37     else:
#      38         idx_to_vocab = [vocab for vocab, _ in sorted(vocab_to_idx.items(), key=lambda x:x[1])]
#
# /content/textrank/textrank/utils.py in scan_vocabulary(sents, tokenize, min_count)
#      22         Vocabulary to index mapper.
#      23     """
# ---> 24     counter = Counter(w for sent in sents for w in tokenize(sent))
#      25     counter = {w:c for w,c in counter.items() if c >= min_count}
#      26     idx_to_vocab = [w for w, _ in sorted(counter.items(), key=lambda x:-x[1])]
#
# /usr/lib/python3.10/collections/__init__.py in __init__(self, iterable, **kwds)
#     575         '''
#     576         super().__init__()
# --> 577         self.update(iterable, **kwds)
#     578
#     579     def __missing__(self, key):
#
# /usr/lib/python3.10/collections/__init__.py in update(self, iterable, **kwds)
#     668                     super().update(iterable)
#     669             else:
# --> 670                 _count_elements(self, iterable)
#     671         if kwds:
#     672             self.update(kwds)
#
# /content/textrank/textrank/utils.py in <genexpr>(.0)
#      22         Vocabulary to index mapper.
#      23     """
# ---> 24     counter = Counter(w for sent in sents for w in tokenize(sent))
#      25     counter = {w:c for w,c in counter.items() if c >= min_count}
#      26     idx_to_vocab = [w for w, _ in sorted(counter.items(), key=lambda x:-x[1])]
#
# <ipython-input-8-0ddc8c58581c> in komoran_tokenize(sent)
#       9
#      10 def komoran_tokenize(sent):
# ---> 11     words = komoran.pos(sent, join=True)
#      12     # 품사 뽑아오기 (명사, 동사, 형용사, 어간)
#      13     words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
#
# /usr/local/lib/python3.10/dist-packages/konlpy/tag/_komoran.py in pos(self, phrase, flatten, join)
#      90             if not sentence:
#      91                 continue
# ---> 92             result = self.jki.analyze(sentence).getTokenList()
#      93             result = [(token.getMorph(), token.getPos()) for token in result]
#      94
#
# java.lang.NullPointerException: java.lang.NullPointerException

# %%
keywords
# Out:
# [('신청/NNP', 23.547713647768784),
#  ('수/NNB', 22.811836601783785),
#  ('강/NNP', 21.454241960226504),
#  ('수강/NNG', 10.182425744140788),
#  ('과목/NNG', 8.694562637075148),
#  ('전공/NNG', 8.078066341054365),
#  ('캠퍼스/NNP', 6.896988519080536),
#  ('학년/NNG', 6.503093991593408),
#  ('학과/NNP', 5.200674291033536),
#  ('학기/NNG', 5.165296025770246),
#  ('변경/NNG', 4.99866376581394),
#  ('신청/NNG', 4.435720093096742),
#  ('경우/NNG', 4.075135093807975),
#  ('사항/NNG', 3.954562719668579),
#  ('홈페이지/NNP', 3.7980268239240274),
#  ('학사/NNP', 3.535740542936699),
#  ('학생/NNG', 3.5323166136482667),
#  ('이중/NNP', 3.473075225782407),
#  ('학교/NNG', 3.4398973534941666),
#  ('후/NNG', 3.3919264322373306),
#  ('확인/NNG', 3.379968127652895),
#  ('부전공/NNG', 3.319764428383667),
#  ('불가/NNG', 3.2667784741945574),
#  ('종합/NNG', 3.1903087910572747),
#  ('클릭/NNP', 3.0619833114452084),
#  ('이수/NNP', 3.0281786944599274),
#  ('글로벌/NNP', 2.856062006489003),
#  ('가/VV', 2.85358034291669),
#  ('조회/NNP', 2.7388157708220353),
#  ('본인/NNG', 2.721967927615681)]

# %%
# 문장전처리랑 가중치 넣은거 어떻게 리스트화 할건지 고민
